# %% [markdown]
# ### Checklist for submission
#
# It is extremely important to make sure that:
#
# 1. Everything runs as expected (no bugs when running cells);
# 2. The output from each cell corresponds to its code (don't change any cell's contents without rerunning it afterwards);
# 3. All outputs are present (don't delete any of the outputs);
# 4. Fill in all the places that say `YOUR CODE HERE`, or "**Your answer:** (fill in here)".
# 5. You **ONLY** change the parts of the code we asked you to, nowhere else (change only the coding parts saying `# YOUR CODE HERE`, nothing else);
# 6. Don't add any new cells to this notebook;
# 7. Fill in your group number and the full names of the members in the cell below;
# 8. Make sure that you are not running an old version of IPython (we provide you with a cell that checks this, make sure you can run it without errors).
#
# Failing to meet any of these requirements might lead to either a subtraction of POEs (at best) or a request for resubmission (at worst).
#
# We advise you the following steps before submission for ensuring that requirements 1, 2, and 3 are always met: **Restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All). This might require a bit of time, so plan ahead for this (and possibly use Google Cloud's GPU in HA1 and HA2 for this step). Finally press the "Save and Checkout" button before handing in, to make sure that all your changes are saved to this .ipynb file.

# %% [markdown]
# ---
#
# Group number and member names:

# %%
GROUP = "63"
NAME1 = "Simon Persson"
NAME2 = "Guo Wu"

# %% [markdown]
# Make sure you can run the following cell without errors.

# %%
import IPython
assert IPython.version_info[0] >= 3, "Your version of IPython is too old, please update it."

# %% [markdown]
# ---

# %% [markdown]
# # HA2 - Recurrent Neural Networks
#
# Welcome to the second group home assignment!
# The purpose of this assigment is to give you practical knowledge in how to implement recurrence in a neural network.
#
# Every day you are exposed to sequences of data. For example text, video streams, audio, financial time series and medical sensors. Recurrence is therefore an important topic in the field of Machine Learning because it has the potential to solve real-world problems including the types of data above.
#
# In this assignment, you will learn to:
#  - Preprocess text data sets
#  - Implement a vanilla RNN cell using only numpy
#  - Text generation
#  - Build a recurrent neural network with LSTM using Keras
#  - Neural machine translation
#
# **NOTE:** Task 1 (Shallow vanilla RNN) and Task 2 (Neural machine translation), are independent from each other. Task 2 asks you to train a NMT, which takes a while (specially without a GPU), so it might be efficient to start with task 2 and leave it running in the background while you solve task 1.
#
# Table of Contents:
#  [1 Shallow vanilla RNN](#1)
#    [1.1 Preprocessing](#1.1)
#      [1.1.1 Loading dataset](#1.1.1)
#      [1.1.2 One-hot representations](#1.1.2)
#    [1.2 RNN cell class](#1.2)
#    [1.3 Training the RNN](#1.3)
#  [2 Neural machine translation](#2)
#    [2.1 Pre-processing](#2.1)
#      [2.1.1 Loading and inspecting dataset](#2.1.1)
#      [2.1.2 Cleaning the dataset](#2.1.2)
#      [2.1.3 Restricting sentence length and shuffling the data set](#2.1.3)
#      [2.1.4 Word-to-index and index-to-word conversions](#2.1.4)
#      [2.1.5 Padding](#2.1.5)
#      [2.1.6 One-hot labels](#2.1.6)
#    [2.2 Implementing a sequence-to-sequence model](#2.2)
#      [2.2.1 Defining the architecture](#2.2.1)
#      [2.2.2 Training the model](#2.2.2)
#      [2.2.3 Evalutation](#2.2.3)
#      [2.2.4 Testing](#2.2.4)
#
# **NOTE**: The tests available are not exhaustive, meaning that if you pass a test you have avoided the most common mistakes, but it is still not guaranteed that you solution is 100% correct.

# %% [markdown]
# ## 1 Shallow vanilla RNN <a class="anchor" id="1"></a>
# In the first part of this assignment, you will implement a recurrent neural network from scratch without using any framework. You will train this network to predict the next character of a text, which will result in a network that can generate new sentences.
#
# Start by importing dependencies below

# %%
import numpy as np
import copy
import matplotlib.pyplot as plt
from utils.tests.ha2Tests import *

# %% [markdown]
# ### 1.1 Preprocessing <a class="anchor" id="1.1"></a>
# #### 1.1.1 Loading data set <a class="anchor" id="1.1.1"></a>
# The text corpus to train your RNN on is going to be the book The metamorphosis by Franz Kafka. Run the cell below to load the text.

# %%
data = open('./utils/kafka.txt', 'r', encoding="utf-8").read()

chars = list(set(data)) 
data_size, vocab_size = len(data), len(chars)
print('data has %d chars, %d unique' % (data_size, vocab_size))
# Out:
# data has 118560 chars, 62 unique

# %% [markdown]
# #### 1.1.2 One-hot representations <a class="anchor" id="1.1.2"></a>
# `data` is now a string, containing the contents of the book, with 80 unique characters. As usual, converting the labels (that is also the data in our case) into one-hot vectors is a good way for creating unbiased labels.
#
# Below is a variable `one_hot_vectors` defined that maps every character in `chars` to a unique one-hot vector

# %%
one_hot_vectors = np.eye(len(chars))
char_to_onehot = { val: one_hot_vectors[key,:].reshape(1,-1) for key, val in enumerate(chars) }

# %% [markdown]
# ### 1.2 RNN cell class <a class="anchor" id="1.2"></a>
#
# Now you will implement the RNN class. For your convenience, this task is split into 4 subtasks, one for each method of the class. These methods will be later linked to a class definition (if you're curious, scroll down to 1.2.5).
#
# Instead of implementing a neural network of arbitrary length like in **IHA1**, you are only going to implement a single RNN cell. At each time-step, the RNN cell will have one input, $\mathbf{x}_t$ , one hidden layer with a hidden state $\mathbf{h}_t$, and one output $\mathbf{y}_t$:

# %% [markdown]
# ![Simple RNN cell](utils/images/RNN-cell.png)

# %% [markdown]
# The output at time-step $t$, referred to as $\mathbf{y}_t$, is computed according to the following equations. Equation 1 and 2 together define the next hidden state $\mathbf{h}_t$, and Equation 3 defines the unnormalized probability output $\mathbf{z}_t$.

# %% [markdown]
# $$
# \mathbf{z}_t =  \mathbf{x}_t \mathbf{W}_{xh} + \mathbf{h}_{t-1} \mathbf{W}_{hh} + \mathbf{b}_h, \tag{1}
# $$
# $$
# \mathbf{h}_t = \tanh (\mathbf{z}_t), \tag{2}
# $$
# $$
# \mathbf{y}_t =  \mathbf{h}_t \mathbf{W}_{hy} + \mathbf{b}_y, \tag{3}
# $$
#
# where $\mathbf{W}_{xh}$, $\mathbf{W}_{hh}$, $\mathbf{W}_{hy}$, $\mathbf{b}_{h}$, and $\mathbf{b}_{y}$ are the parameters of the RNN cell.

# %% [markdown]
# Calculating $\mathbf{h}_{30}$ means that you need to need to have calculated every earlier hidden state $\{\mathbf{h}_t | t \in \{0, 1, ..., 29\}\}$. This can easier be understood by always imagining an unrolled RNN cell:
# ![Simple RNN cell unrolled](utils/images/RNN-cell-unrolled.png)
#
#
# Since it is a multiclass classification problem, the softmax activation function is going to be used to normalize the output of the RNN cell $\mathbf{y}_t$, defined as
#
# $$
# \mathbf{p}_t = softmax(\mathbf{y}_t) = \frac{e^{\mathbf{y}_t - max(\mathbf{y_t})}}{ \sum^j e^{y_{j_t} - max(\mathbf{y_t})}}. \tag{4}
# $$

# %% [markdown]
# #### 1.2.1 The initalization method
#
# The first step in creating the RNN class is to create its `__init__` method, where we create all the necessary attributes and initialize them. Complete the `init_routine` function below. Later this will be linked to the `__init__` method in the `SimpleRNN` class, so you're now developing the constructor of that class.

# %%
def init_routine(self, input_dim, hidden_dim, output_dim):
    """
    Initialize the weights of the RNN and define a cache with the starting value of the hidden state

    Arguments:
    self - an object of the class SimpleRNN
    input_dim - an integer representing the number of inputs
    hidden_dim - an integer representing the length of the hidden state vector
    output_dim - an integer representing the number of outputs

    Attributes:
    input_dim - attribute initialized with the value of the argument `input_dim`
    cache - a dictionary holding the values of `h_start`, `xs` and `hs` from the previous forward propagation call.
            h_start - the value to initialize the hidden state with when `forward_prop is called. The value of
                      `h_start` should be initialized to a `numpy.ndarray` vector of zeros 
            xs - the list of `xs` used in the last `forward_prop` call. Later used in `backward_prop`. Can be
                 initialized to `None`
            hs - the list of `hs` calculated in the last `forward_prop` call. Later used i `backward_prop`. Can
                 be initialized to `None`
    W_hh - weight matrix of shape (hidden_dim, hidden_dim) and type `numpy.ndarray`. 
           Initialized randomly from a normal distribution of mean zero and stddev 0.01
    W_xh - weight matrix of shape (input_dim, hidden_dim) and type `numpy.ndarray`. 
           Initialized randomly from a normal distribution of mean zero and stddev 0.01
    W_hy - weight matrix of shape (hidden_dim, output_dim) and type `numpy.ndarray`. 
           Initialized randomly from a normal distribution of mean zero and stddev 0.01
    b_h -  bias of shape (1, hidden_dim) and type `numpy.ndarray`. Initialized to all zeros
    b_y -  bias of shape (1, output_dim) and type `numpy.ndarray`. Initialized to all zeros
    """

    self.input_dim = input_dim
    self.hidden_dim = hidden_dim
    self.output_dim = output_dim
    self.cache = {
        'h_start': np.zeros((1, hidden_dim))
    }
    
    # YOUR CODE HERE
    self.cache['xs'] = None
    self.cache['hs'] = None
    self.W_hh = np.random.normal(loc=0,scale=0.01,size=(hidden_dim, hidden_dim))
    self.W_xh = np.random.normal(loc=0,scale=0.01,size=(input_dim, hidden_dim))
    self.W_hy = np.random.normal(loc=0,scale=0.01,size=(hidden_dim, output_dim))
    self.b_h = np.zeros((1,hidden_dim))
    self.b_y = np.zeros((1,output_dim))

# %% [markdown]
# The following cell tests if your implementation is correct.

# %%
test_init_routine(init_routine)
# Out:
# test init passed

# %% [markdown]
# #### 1.2.2 Forward propagation
#
# Now that we have an initialization method for declaring objects of our class, we need a method for performing the forward propagation step. Complete the `forward_prop_routine` function. This will later be linked to the `forward_prop` routine of the `SimpleRNN` class.

# %%
def forward_prop_routine(self, xs, reset_h=False):
        """
        Performs forward propagation of the input `xs` in sequential order, and then returns all predictions `ys_pred`
        The steps are: [Input x] -> [Hidden h] -> [Output unnormalized z] -> [Prediction probabilities y]

        Arguments:
        xs - a python list of one-hot characters to predict the next character from,
             Has a shape of list([1,OUTPUT_DIM]) and length `len(xs)`
        reset_h - boolean value, whether or not the hidden state should be reset

        Returns:
        ys_pred - a python list of prediction probabilities for each character in `xs`. There are `len(xs)`
                  elements in ys_pred, each element `i` of shape (1, output_dim) and type `numpy.ndarray`
                  that contains the probabilities of what the next character xs[i+1] can be

        Example:
        xs - [np.array([0,0,1]), np.array([0,1,0]), np.array([1,0,0])]
        ys_pred (ground truth answer) - [np.array([0,1,0]), np.array([1,0,0]), np.array([...])]
        """
        # initialize the list of predictions
        ys_pred = [0] * len(xs)

        # load the last hidden state of the previous batch
        if reset_h:
            self.cache['h_start'] = np.zeros((1, self.W_hh.shape[0]))
        hs = {-1: self.cache['h_start']}

        # YOUR CODE HERE      
        def softmax(yt):
            max = np.max(yt)
            numerator = np.exp(yt-max)
            denominator = np.sum(numerator)
            return np.divide(numerator,denominator)     
        
        
        for i in range(len(xs)):
            z = np.dot(xs[i],self.W_xh) + np.dot(hs[i-1],self.W_hh) + self.b_h
            hs[i] = np.tanh(z)
            ys_pred[i] = np.dot(hs[i],self.W_hy) + self.b_y
            ys_pred[i] = softmax(ys_pred[i]) 
        
        
        
        # save list of hidden state in cache to use later in backprop
        self.cache = {
            'hs': hs,
            'xs': xs,
            'h_start': hs[len(xs) - 1]
        }

        return ys_pred

# %% [markdown]
# The following cell tests if your implementation is correct (it assumes you correctly solved task 1.2.1):

# %%
test_forward_prop_routine(init_routine, forward_prop_routine)
# Out:
# test passed, dimensions are correct

# %% [markdown]
# #### 1.2.3 Backward propagation
#
# Now that you developed methods for initialization and forward propagation, it's time to implement the backward propagation algorithm as a method for our class.
#
# The cross-entropy loss will be used for this task, and just like in **IHA1**, backward pass of the softmax activation function and the cross-entropy loss can be combined into a simple formula: $\mathbf{\hat{p_t}} - \mathbf{p_t}$, where $\mathbf{\hat{p_t}}$ is the predicted output vector for time step $t$ and $\mathbf{p_t}$ is the ground truth one-hot vector for time step $t$.
# The full collection of backward pass formulas that are required for implementing `backward_prop_routine` are shown in Equations 5-12:
#
# $$
# \frac{d\mathcal{L}_t}{d \mathbf{y}_t}=\hat{\mathbf{p}}_t-\mathbf{p}_t \tag{5} ~,~ \text{ for } t=1,\dots,N,
# $$
#
# $$
# \frac{d\mathcal{L}}{d\mathbf{W}_{hy}}=\sum_{t=1}^N\mathbf{h}_t^T\frac{d\mathcal{L}_t}{d \mathbf{y}_t}, \tag{6}
# $$
#
# $$
# \frac{d\mathcal{L}}{d\mathbf{b}_{y}}=\sum_{t=1}^N\frac{d\mathcal{L}_t}{d \mathbf{y}_t},   \tag{7}
# $$
#
# $$
# \frac{d\mathcal{L}}{d\mathbf{h}_t}=\frac{d \mathcal{L}_t}{d \mathbf{y}_t}\mathbf{W}_{hy}^T+(1-\mathbf{h}_{t+1}^2)\odot\frac{d\mathcal{L}}{d\mathbf{h}_{t+1}}\mathbf{W}_{hh}^T   \tag{8.1} ~,~ \text{ for }t=1,\dots,N-1,
# $$
#
# $$
# \frac{d\mathcal{L}}{d\mathbf{h}_N}=\frac{d \mathcal{L}_t}{d \mathbf{y}_N}\mathbf{W}_{hy}^T,   \tag{8.2}
# $$
#
# $$
# \frac{d\mathcal{L}}{d\mathbf{z}_t}=(1-\mathbf{h}_t^2)\odot\frac{d\mathcal{L}}{d\mathbf{h}_t}   ~,~ \text{ for } t=1,\dots,N,\tag{9}
# $$
#
# $$
# \frac{d\mathcal{L}}{d\mathbf{W}_{xh}}=\sum_{t=1}^N\mathbf{x}_t^T\frac{d\mathcal{L}}{d\mathbf{z}_t},   \tag{10}
# $$
#
# $$
# \frac{d\mathcal{L}}{d\mathbf{W}_{hh}}=\sum_{t=1}^N\mathbf{h}_{t-1}^T\frac{d\mathcal{L}}{d\mathbf{z}_t},   \tag{11}
# $$
#
# $$
# \frac{d\mathcal{L}}{d\mathbf{b}_h}=\sum_{t=1}^N\frac{d\mathcal{L}}{d\mathbf{z}_t},   \tag{12}
# $$
# where $\odot$ is the <a href="https://en.wikipedia.org/wiki/Hadamard_product_(matrices)">hadamard product / elementwise multiplication</a>.
#
# Complete the `backward_prop_routine` function below. This will later be linked to the `backward_prop` method of the `SimpleRNN` class.

# %%
def backward_prop_routine(self, ys, ys_pred):
    """
    Performs backward propagation, calculating the gradients of every trainable weight. The gradients should
    be clipped into the interval [-5,5]

    Arguments:
    ys - a python list of true labels (one-hot vectors of type `numpy.ndarray` for every character to predict)
         has a shape list( (1,OUTPUT_DIM) )
    ys_pred - a python list of predicted labels (one-hot vectors of type `numpy.ndarray` for every character predicted)
         has a shape list( (1,OUTPUT_DIM) )

    Returns:
    gradients - a dictionary of the gradients of every trainable weight. The keys are the weight variable names
                and the values are the actual gradient value
    """
    
    # extract from cache
    hs = self.cache['hs']
    xs = self.cache['xs']
    
    # YOUR CODE HERE
    N = len(ys)    

    Lt_yt = np.zeros((N,1,self.output_dim))
    dW_hy = np.zeros((self.W_hy.shape))
    db_y = np.zeros((self.b_y.shape))
    dW_xh = np.zeros((self.W_xh.shape))
    dW_hh = np.zeros((self.W_hh.shape))
    db_h = np.zeros((self.b_h.shape))
    dh_t = np.zeros((N,1,self.hidden_dim))
    dz_t = np.zeros((N,1,self.hidden_dim))
    


    for t in range(N):
        Lt_yt[t] = ys_pred[t] - ys[t]
        dW_hy += np.dot(hs[t].T, Lt_yt[t])
        db_y += Lt_yt[t]
        
    for t in range(N-1,-1,-1):
        if t == N-1:
            dh_t[t] = np.dot(Lt_yt[t], self.W_hy.T)
        else:
            dh_t[t] = np.dot(Lt_yt[t],self.W_hy.T)+np.dot((1-np.power(hs[t+1],2))*(dh_t[t+1]),self.W_hh.T)
    for t in range(N):
        dz_t[t] = (1 - np.power(hs[t],2)) * dh_t[t]
        dW_xh += np.dot(xs[t].T, dz_t[t])
        dW_hh += np.dot(hs[t-1].T, dz_t[t])
        db_h += dz_t[t]
            
            
            
            

    # Clip gradients to prevent explosion
    for dparam in [dW_xh, dW_hh, dW_hy, db_h, db_y]:
        np.clip(dparam, -5, 5, out=dparam)

    # save gradients into dict and return
    gradients = {
        'W_xh': dW_xh, 
        'W_hh': dW_hh, 
        'W_hy': dW_hy, 
        'b_h': db_h, 
        'b_y': db_y
    }

    return gradients

# %% [markdown]
# The following cell tests if your implementation is correct (it assumes you correctly solved tasks 1.2.1 and 1.2.2):

# %%
test_backward_prop_routine(init_routine, forward_prop_routine, backward_prop_routine)
# Out:
# Your BPTT implementation is correct.

# %% [markdown]
# #### 1.2.4 Applying the gradients
#
# Finally, we need a method that updates the paramters of the RNN cell, given the computed gradients of the loss with respect to each one of them. Complete the `apply_gradients_routine` function below. This will later be linked to the `apply_gradients` method of the `SimpleRNN` class.

# %%
def apply_gradients_routine(self, gradients, learning_rate):
    """ Performs the weight update procedure. Updates every weight with its corresponding gradient 
    found in the `gradients` input dictionary

    Arguments:
    gradients - dictionary containing (key, value) pairs, where the key is a weight variable name of
                the `SimpleRNN` class and the value is the gradient to apply to the matching weight
                Example: {'W_xh':0.04, 'b_h':0.11}
    learning_rate - the learning rate to use for this iteration of weight updates
    """

    # YOUR CODE HERE
    self.W_xh -= gradients['W_xh'] * learning_rate 
    self.W_hh -= gradients['W_hh'] * learning_rate
    self.W_hy -= gradients['W_hy'] * learning_rate
    self.b_h -= gradients['b_h'] * learning_rate
    self.b_y -= gradients['b_y'] * learning_rate

# %% [markdown]
# The following cell tests if your implementation is correct (it assumes you correctly solved task 1.2.1):

# %%
test_apply_gradients_routine(init_routine, apply_gradients_routine)
# Out:
# test apply gradients passed

# %% [markdown]
# #### 1.2.5 Putting everything together
# Now that all the parts of the RNN are implemented, we can define the class. The following cell defines the `SimpleRNN` class, linking all the functions you developed in the earlier tasks to corresponding methods. Additionally, it also implements another method, the `sample`, used to generate output from a trained RNN. Note that you don't have to change anything in this cell, just run it after solving the previous tasks.

# %%
class SimpleRNN:
    """
    The simple RNN class definition
    Implements the initializations of the weights, the forward propagation from `x` to `y_pred`,
    the backward propagation with respect to each trainable weight and the update weights rule.
    """
    
    # __init__ method is now the initialization_routine function
    __init__ = init_routine
        
    # forward_prop method is the forward_prop_routine function
    forward_prop = forward_prop_routine
    
    # backward_prop method is the backward_prop_routine function
    backward_prop = backward_prop_routine
    
    # apply_gradients method is the apply_gradients_routine function
    apply_gradients = apply_gradients_routine


    def sample(self, seed, n, char_to_onehot, chars):
        """ Given a seed character `seed`, generates a sequence of `n` characters by continuously feeding the output
        character of the RNN at time t as the input for the next time step at time t+1. If the RNN is trained well, 
        this method should be able to generate sentences that resembles some kind of structure. 
        The character should be generated with a probability of the outputs of the network!
        
        Arguments:
        seed - a first character of type str to feed into the SimpleRNN
        n - the length of the character sequence to generate
        char_to_onehot - a dict that maps keys of characters to its one-hot representation. 
                         You created this dict earlier in the lab
        char - a list of chars (vocabulary). You also created this list earlier in the lab
        """
        
        saved_cache = copy.deepcopy(self.cache)
        
        char_list = []
        h = self.cache['h_start']

        # seed one-hot char
        x = char_to_onehot[seed]

        for t in range(n):
            """ not relevant anymore
            # perform forward prop. `forward_prop` is not called because then the hidden state for the
            # training procedure will be overwritten by the hidden state generates by this sampling procedure
            h = np.tanh(np.dot(x, self.W_xh) + np.dot(h, self.W_hh) + self.b_h)
            y = np.dot(h, self.W_hy) + self.b_y
            p = np.exp(y) / np.sum(np.exp(y))
            """
            p = self.forward_prop(x)[0]
            
            # randomly pick a character with respect to the probabilities of the output of the network
            ix = np.random.choice(range(self.input_dim), p=p.ravel())

            x = np.zeros((1, self.input_dim))   
            x[0,ix] = 1

            # save the generated character
            char_list.append(chars[ix])
            
        self.cache = saved_cache

        return ''.join(char_list)

# %% [markdown]
# ### 1.3 Training the RNN <a class="anchor" id="1.3"></a>
# In this section, code has been provided to you to train a `SimpleRNN` cell by predicting the next charcter in sequence.
#
# The code below has the following properties:
#  * Loop over `data`, using `seq_length` words at a time as a batch to train with
#  * When `data` has been fully iterated through, start over again
#  * Start over again with `data` in an infinite loop and then interrupt the running cell
#  when results from `sample` are good enough.
#  * Perform `forward_prop`, `backward_prop` and  `apply_gradients` with each batch of characters
#  * every 1000th iteration:
#      * compute the cross-entropy loss of the current batch
#      * sample a character sequence of length 200
#      * print the loss and the sampled sequence

# %%
rnn = SimpleRNN(len(chars), 500, len(chars))

# the number of characters to perform one update of the network with,
# can be thought of as a batch
seq_length = 25

# the learning rate to use
learning_rate = 0.001

while True: # the infinite loop
    
    # iterate over the data set
    for i in range(len(data)//seq_length):
        
        # convert to one-hot
        xs = [char_to_onehot[c] for c in data[i*seq_length:(i+1)*seq_length]]#inputs to the RNN
        ys = [char_to_onehot[c] for c in data[i*seq_length+1:(i+1)*seq_length+1]]#the targets it should be outputting

        # fp, bp and update
        ys_pred = rnn.forward_prop(xs)
        gradients = rnn.backward_prop(ys, ys_pred)
        rnn.apply_gradients(gradients, learning_rate)

        # print loss and sample a sentence every 1000th iteration
        if i%1000==0:
            loss = np.sum([ -1.0 *np.sum(y * np.log(y_pred + 1e-8)) for y, y_pred in zip(ys, ys_pred) ]) # x-entropy
            print('iteration %d, loss: %f' % (i, loss))
            text = rnn.sample('a', 200, char_to_onehot, chars)
            print(text, end='\n\n')
# Out:
# iteration 0, loss: 103.189606
# uuYUeç!qbWDçzhQE)-jIoo!A.mFGc;DkT?WLfBç"FPqEwFtçPDçneMh'a!Dk;UodlU";SvbyrAMçMPonAHm;hiTT-j()OHsuMY"kSIC,HWSGdzvg
# )Bog:YIumFIYh
# s-)snNvçWHJ;BCHDgHP:l(fsmSlxugaQeBH?H.;Chuxr
# eCWoeçEo:-v-mgBwy)qtHfCNPIxI
#
# iteration 1000, loss: 78.656703
# e tsetvctwerisrclnysplesgsasne 'urh,i eesLh!d nuarcfik otideo.ffa i ooches  tte.cdt,httdh.hshfldyrdg uild ie r t,rirGstgeiltv h rw l tVyuhsrifswo   rr ae cllge,g  kaa,eet,etiot,l thitho nro r,iiygstuT
#
# iteration 2000, loss: 69.727664
# fb de awabla s ho bnso er wntudersc oi ths s rsrme dat sosrrer  s aoh(d xoe toyirn hsilidnofeflgh hrhhuaep rhnioc.lcred,sns ah wrwhgetcreege  oser lno  gloarnse t h  ye yrawnodee  uem n ooi ee r oo ir
#
# iteration 3000, loss: 67.898546
# on Ghisewncde ooihlmwhub mo ieos naY,rod rwmmuhat haallgrdiy sotstnNda enr gu aie t aha cgsgaae nosasag ffdem was nonolg ,tiua dathafrpgpoeaherenisBr her hlkoaC?core ans aortirn nhea sisuiea hecgweira
#
# iteration 4000, loss: 68.731909
# c.g lrds taptreederereoQrren"utr;noat inH rhto fe bn towls ;e uo)e ofsrer ihere, nbtt n!s aMitk dmhiSn hiactceanitlroscto tgey woj,lzeothe,pytorvuwstn theGoisotsese thin whe hef ahe th ho hid onm thac
#
# iteration 0, loss: 64.923602
# nt fifynisrcdto ther biycroilc kaat an thef fmit on they emelthe wodiy sln the tiif kr:Dr
# r mmet mor coy weodl boelm" bhet thosMd nine rrnl orath ther grdQe thit inrthesd bgon. Hod sto nhit nea. srter
#
# iteration 1000, loss: 66.060546
#
#  le kidrerovit pnle tho snmf oth thens.
# use bers anvegy oppisteind ooygy lste srs nfnrid hiloat wrlid eid th se has arhew therenty pisinithed Jler thernheyr, bd mased
# evoctr the msat the ione awad
#
# iteration 2000, loss: 56.290850
# y hheay Ios hehol hr asrer iim aam wreoo sraan whe hetha keNk it ham hore toresllawt trele la, the hn hin mory foat the be woe santh bgon bed iule hepds -recad. .he intbarkoc for her-n bamdb fane wpam
#
# iteration 3000, loss: 64.215076
# dhee Eaclroft, Gourithe foamad Iondende he wava c nasnp. he tothand hom thor thace noat atht mhen fesom bald llut uus bod se heam taswend touthe. pouksem owtius fo whaf cftherenAtous nolcmact hasthe p
#
# iteration 4000, loss: 58.075018
# nd her inl wef ourlelkeremes thin n
# d romiag they ald andrther thathcad sheUnd seint aann Jocis barl him bfay the solre soon dos watce wgsis thiwd the then hather nhe, ond iuthe eag tho: ahed om teuil
#
# iteration 0, loss: 58.579910
# n. he biturid the wore ot thand the d aths hes ff aim shen he shelFhs orerrghar gust lhand tim. "re snry"t asogeth medn. bo whe glland, Ae hif snel .tr mowq nitd erst w. thir what on. there, them coot
#
# iteration 1000, loss: 62.354733
# ald anms beno nhit up chis uth od we sarlron 'atueg wor sor these hire Pure ter, beHeyun, .ist opy se an, " wtoil)u. the g locs mawnrotly ule batl sjors barm the rilsg houn, fom "nent  onrmull, ber te
#
# iteration 2000, loss: 52.938056
# then, dre warket bukneb angove, her bothay Iveuly nuthen buiwht ermame dasher ham hate roment one n and we pauzly xowif tuveng, soshered wher whe she anls znonle hiud are ote fo ha cher anes alet ohe
#
# iteration 3000, loss: 64.343892
# n,, or him acwase nrin wwea resserind waunlid sfo therermreltigher hinc hacinging theg hlad, sisgowis f lishenv helk,ath rihing of oule he hirgeded sed hut meed nouls haygob
# ding or mopset suver dimc'
#
# iteration 4000, loss: 47.873123
#  ht woow hil mast nis mithin tedtor, aYpenin hry ved werr,ec, Gngisher touc, bet th atoecar tou, shed be woo pevoof amtake. father toomk foogey fouc auimenyy him eather sing roenas torett . gusinxt nw
#
# iteration 0, loss: 54.724604
# s nof she mitN tor's for nok wha cher wid wo at
# , he s mesiep ouvt an list han, wore,,. theatveFm he dy apr' ho ble orr ned wilk ent tisthe wh ssuwall regtor s rablwing. Wnengeugat, atter lleco win f
#
# iteration 1000, loss: 60.747277
# dy ou her talent wace warsthem, Tas ong ckewcsidk meI kathet toyed tound his was nert, tert Fof dven th it on the fooly eno bis lung net beay ras reenen thom n anm waind bo htig fervard his . hall the
#
# iteration 2000, loss: 51.292546
# inen the hay thed pafyinl weredd. Oery waig women ffapeplaso reve havast has sowe the hiind sta. ,hay boded homevere tom ses Gtsmecx fron; bpewr chet int hatren le he has thamktregre derod bat fougs o
#
# iteration 3000, loss: 65.473316
# tr, as freght monghe soll puce stot spas. Npok lstithe hionginim fath s face farlet, awad wadand whad rrosf nollprerould weratly lool to sedpin'st of frou't tome. Ixo kent arpif chor ofte sidg wathers
#
# iteration 4000, loss: 39.084095
# rtorze and wint ofrwat mealy his seencimn, on fad plthay Va theion theer th he wnigtougad. Hus oreote thes -ling sithimed, anen avend him sivenr sally chay anoon GfowewallWokain towas sewyoth evouk wl
#
# iteration 0, loss: 53.815608
# nd le war thate p, chald ma'l tout, bott hert tlouthe foocen fhe thi!m ath, ffrece diom dint tar to mth tom'l inveg ancs at kred th urd,i. Lt her kan atnof tur gither she meokad, wavend pote frrmyathi
#
# iteration 1000, loss: 60.034711
# skucly aad ole worteD. Soxke by uld chtr, meveld om's latlen, karkis penring tuthe He teast haice onen thatf nom wing of caif n canwatren, tharen Qlemwand tore wan no the hid cowh s, iop beld ar ioulk
#
# iteration 2000, loss: 50.491501
# sher Hichirghe the pathrroffre- fiche woul hed har torvemothe ghe chim ar un for ay heathy e coorlyf, her wathene then wikg out outrenot hip Wofkeremingfist ory beak bet an hat we ane thingegt, Iore e
#
# iteration 3000, loss: 65.506763
# ter aam hit hay s otthl drece han Gregald couwhr, shed ciimn wio was icQitinbist ro cowemly hiss aid pomsenstingod bningely sist. Ino hadcopedong h wher tor, aged thed te poll tlown thevencore not win
#
# iteration 4000, loss: 34.230505
# d?cary aneasrefircoped dace bed whit wasy ourcorit mhissumcumege hirssard thear to tound at alig; meringor, qxthare leand ciplt wingby wirsuly coacpmen; on thout do noweins stoo hedowa gohess toom ore
#
# iteration 0, loss: 52.239961
# rlo bentirap" ing in ther agand his theing s ould to hor wan that meryon yrveroke wlmot Gred caSk gor ke becomle gord meder, hire thav ossed to srofVenclin. Grem, cers to cow ar and bonest ot me this
#
# iteration 1000, loss: 59.266712
# tx; seomqs no? the hiom wirv alt "h pardss, Is cronto . Aul Fime to inut du him coven mouts proule ouly and coult ce the fhe ching oll streno, they p of the hang thit vean lasntadG chente conmimoff "h
#
# iteration 2000, loss: 50.178491
# t has monk vouthel" betoreg are as no thrugath bok, suthlege, brto the her aread, as ero, eveand he woor, alymorey lothon hns oulea to his morks, suthee tored chat ho has beingtryterndy's loomid, he G
#
# iteration 3000, loss: 64.354005
# ke ", brofe rnabse pbeer ba the fist chen to ppobly thever not nigmly hit padtory'mu dord. Grank Gregolle semtas the mxat hepverd coully beane, fthe wave monthery whe paarins Gregortt ablunt stored go
#
# iteration 4000, loss: 32.056039
# they liom dissurs on tore covear ainumont afieg theitin, ayver, tery doreild woun beiver, ofliighs eamly misined or cad orongay saveree to thes way wuttitr wish, at outher Gregor to ham on tow sheway
#
# iteration 0, loss: 51.116116
# nd ware y thet seemuxc; no weer bets the bedr sing thit's shis fvemom Mo shithing athire wishiy se the Mhe tad theme wamen,, the; th om il; an the they or afr tole lormutly, Luss evan nsy thoe dse the
#
# iteration 1000, loss: 58.290740
#  do and niouch io chas is coren', she coll. Jus oror ave tily the cingo he win latibo fnot inong nero ghe fouthe coult thing whour he sepurs uf that ss her chise ory inow, was bit tad ,ingtout, m"oulr
#
# iteration 2000, loss: 49.341694
# ll and wo ke lusker;,wasp ally.
#
#
# Greghelu, deavathay uh wooreaj", ppooming hichos ee perimelt at he was ant eros iaslyur avire wntont beliQs buth remimed to comena hos hive doreat, ant mupGse anded h
#
# iteration 3000, loss: 62.934129
# tly wara sean theve nom, sus mither, on had Sadatlcere pime so hiveved har turtere. ang him..
# jHich to stftabe, Greer and moully alist the uven fur nomodll, Gregh his suonge ingoule doow qlomp, bof te
#
# iteration 4000, loss: 30.761883
# ll qecasonum ked ie evereicing timy hid ragher it hin ferioute tief that the bing, they andite aliace har hid one kist af wash if him the ither avilverrowey asce iner as in to iot; thar ous nowayin, a
#
# iteration 0, loss: 49.369123
# nd meit. Ather he t ant, sthey rrem at ther, bat war. Stwat had batt oushe take ro cowper, thit was they, Gregary book al int him tad ceras it ard batr. Hed labmentiwht. Thas. Gregon and ont har mut p
#
# iteration 1000, loss: 57.525847
# nd whe fuld the ruad a dainy do the maws -reist herrs mist and tx all the mot pernett.
#
# L"wath therre: , ank war the kikgkd in of of the mass d oned le che tho gay in?cUistl"th, thit je menon an boucl
#
# iteration 2000, loss: 48.262322
# y oitally, awat Gregor bory uletery storcungith qlaile alade aod af hat was in allune te thit She owe fore the foot wsate hat him, had iothonkl ot his all ous ffither onther haly do tory if ho belo or
#
# iteration 3000, loss: 62.167239
# ly, in soll rind sowhill about mutullyy ut whit wooll, Gregor swat indoy of to clict, furtist way, thould, stord the tapres the enon ghing a lasline torennd Iy his buthed, hil shat tollwfuct.d
#
# W hime
#
# iteration 4000, loss: 30.004878
# lly, thouad te ittoager it mich his loacs nox Bxon i( Ius washer brown trost fheeven; ifppeind gutheO howaplened aub rospmemeryin bewinbighing thour out then romsken toppeed. Ir.
#
# Ollaid dot oig teall
#
# iteration 0, loss: 47.672343
# nd the fmor's ingt tiag the t eon frread lpminis, and he deve tiple sat iven Grege. Tuld patlids ovthet ered awfy to thaim fnit thet out thairs iomsy with a'd lein'd perm ram, the would atred whtid an
#
# iteration 1000, loss: 56.809607
# ble the fairs then wly far and a way statr the ghan wiofly juy nemseng and turepld shist on then, batige" forr wis and war nithel t omate fleg to cepereose pursely though, I" that no ghisk f ant buin
#
# iteration 2000, loss: 47.058753
# y had aly ielly loubs appeaply aveiy Gregor and iblf aryaur and tr ak in wat har aevele. Bhing an) with thes eare to that hedly sigo himstwinng the go thar then wo chit his leet;, the where proneate h
#
# iteration 3000, loss: 61.933274
# nded "res efrocked anyen thape his agast bvens.
#
# Gregng not, but that thoug the inge him Iis pistury. The ffrretce urout ditsfitifgon, "fsthe his wing allatr was eredtly, ivin shey mo-ter'nd chat Greg
#
# iteration 4000, loss: 29.682618
# rd at h's seclickngothe ftomes not jither, nying jotier apse?ver whengrrank exsill as and his faning theupighe doonharny mmellignt of ofithrnenoninish aroolem, the daverorensore the gay cattout ous ha
#
# iteration 0, loss: 46.993294
# ll hir siof rack chewc moke fad hed, wGreg veded lot the fintn shey ho sime. As thetr gay baing sirvinang ass. Ixer thet Mited him thit wonded and taice eot wof thed, ast, chem what breave had win the
#
# iteration 1000, loss: 55.308588
# t ot avea fpreich. Mewrowh eadl. Les but roung ho gepret, Tcometly the thend bewas intcoucpleast sa!d w. Sevanimellom tay whife ngorer leNt a'sa fisw platt had the dourd cooln - arpo go dreven t abeck
#
# iteration 2000, loss: 45.566264
# nkely avBund on Gregor that un se torner he hedr ellen for't non the everet unonis songerwasles to heved's dor(ing heade neallourd dod's then.,'ved batey us whewe chate d coule enyey mpingrs an im the
#
# iteration 3000, loss: 62.304522
# n in the comaln onged wikled onght or to donkroug the eviry chit be, eflly fill ffrrabsid bat she hrors brcevith oug neandds not wand fored in the waying ahe were fuld simuld rowh leckifu'dir
# - pupt s
#
# iteration 4000, loss: 29.444607
# ly. Ds shing, bitheather egentren t leck chawh hirked and Greger soow thole bugith a and acout dithe. Them sereagry the atter wathar and cfiof held andan in whiobe Gregor outed to hardly Gregor's fish
#
# iteration 0, loss: 46.891002
# nd whre the from I the strat of they op a with a sthit the moum list loom whio had hald gher stwith wile and bat, bpenbained yfroted in int, mpunging sidattoutlenf, ontigen, whet che tr. Oghl has in h
#
# iteration 1000, loss: 53.488793
# nct, the pind and uther ts reet. Hee thurc. Sfion, to sed theich themped ht seme thiom he wonlsad"
#
# Gregur was mo, any that and towte the doll he deor thet hiongo they or, mouce extout" hillsht athers
#
# iteration 2000, loss: 44.613597
# le to ghars uf horisald oo had nes thanked wat reeminy aw he vell oven reat elly to son to ecought, than he way norlaila a loon hid distor out whele himçt apousing to demy eay but realsisly that one;
#
# iteration 3000, loss: 62.427090
# n she tomped three hissad Gregor was exthe aidet liss, brow is the cimsint boums shouch, uveall mied araine semparingo as a lingor qule donllibust laoked she ciefl the olligen to dad sowe thar'c meall
#
# iteration 4000, loss: 29.044286
# ntiontomesostint whthab(er fase "tould. Toinowes whough. He to that wheher siof afy any muchen ove at bithor save thetr go ofTrosted an the wanly so hids mother, and wimwa devenen they sokn as ave and
#
# iteration 0, loss: 46.583760
# ide? Che tle intsong hus chemob"hy, was the, if comstinu harh ald cals statker undible nouth oven as himush one ste theie ffat, he -edet on. Saw, the cal. thes were har and dowh with forsu alred lof t
#
# iteration 1000, loss: 51.693394
# ni" Istout lorlen tay het had ourinktasthint, thed do rohes mong he courd seable,.
#
# "Greger, th treed sook, che fuit oren thont oul chay he tiof he clook. Seer to munt to it quattot butn whuth he ploc
#
# iteration 2000, loss: 44.396322
# ll er tr and hhat ghthen hid outher was thate hly bock afrease foop ou, owh room frearwasts every hevembed wook. Theres, anwernCtitu hthere now way hur his mosten -ores iney a pickene sureate sughe ba
#
# iteration 3000, loss: 61.924989
# liteen what efreched from icleray fortrint ad thing rook nows littly tulling, and non it wlels gon. The forlowill was nothing rook simfercl. Hak, the fratle", had bedhick, the foo stitim she from the
#
# iteration 4000, loss: 28.649273
#  a piakid wap out acouth;N, pettorew ham theil was sumious theimed wat herfortonged hem and butkabled to mack ant eveny coom, at of wattout aby then the unowed had wathea wryenf ast, whire, thaupwos s
#
# iteration 0, loss: 45.887475
# nd mere theers atist was sponing outureve; as ict of chas's ind ghithre olly pedced ablitt, now the male siccianef nots her it aly shay ble sthald go baking ferne chaigh what we, "t thos was Gregit so
#
# iteration 1000, loss: 49.986477
# t outhtue mang Hest to ho ffr thoy proms't a from there he pliad. Hes of abre to sispeetew off reevien her lot wfore medon ob to chly in becking hlis mith himsed awar siatlly anhe doo to re cented wis
#
# iteration 2000, loss: 44.450113
# w he mome heath, anthar(row momatly und out boo the sty thouge, horgof wouch at a once his froul jang thing foo falyone coil thau bus thene has bother opren shacked froing to towryt ap that bessore to
#
# iteration 3000, loss: 61.140653
# lly ctord haw of Greger most the cheir, whit with undist worl hr hes would, abread him his nothery bot. Gregor make suafrist his loft prein him. Qave GregerofI there the pleblary, and whea distice ald
#
# iteration 4000, loss: 28.342797
# l byinging anto their peeding copeavion ald the tightis. The leven ig t his wathough, this my.A; sickiftint, with a waythtaking the finctana theive chith he was magher? Iut dighe thome by aur oved to
#
# iteration 0, loss: 45.415179
# nd be, the quntint lert and nowayisally been sict. Then ghoug the tires him llfertuticaly, but was d dild one. Tas mon lon loa to get lectusall. Tam. Ald in hay. Heales, bat wour. Then they hed and re
#
# iteration 1000, loss: 48.303081
# tuill. Mvery the faplong pespert leaded aver ser and alfort. Supon - hepr ont he courd his foim in mecked he had nowh und becr chelr at him fent. "Ad turd! I she deving comid qumed the furt firte the
#
# iteration 2000, loss: 44.797397
# tren legnthandy she meel fumened rab:ed onlet hid timing anoubur the mither Gregor. That one onay, him ain net betone in ontick the koor, dway thon's netoon he. Than sery wow ment's barnked that who f
#
# iteration 3000, loss: 60.224384
# ing wore breanced abew yom and to char gare some on and it wronced'y hpremen'trong", was she wasple'p and toreaisllbods chimsel his montibly orem, she begr dorrad upp his flor in chat to more hrromed
#
# iteration 4000, loss: 27.983217
# unt emouthing sustand om time Gregor; out thie bad, as couch or got het reteack br,abyed peastring allay on to did whervar muen teable tryough the badly withoucldey simabute he' mpoherich at them chen
# iteration 0, loss: 45.131108
# pped yee corithen a did wowh. Vasind that whing to gene ryant, ald and cbecing to his ftelugh thear wasse, wad under she msleaghr" had they heving, the way noused nit have I rount on a dimal"
# TAy lark
#
# iteration 1000, loss: 46.688709
# ting as they dad not she way she cuiff curexit, when was himserne bo there simfrot chiofplly he was so the terr to reess bsing was llet orme the then seech in bling a)se thing to bry pismecing and noc
#
# iteration 2000, loss: 45.285481
# n toor that whates t haid no wothing, anl ms bere, beby a morith.
# "This that thenedy, aby to her thrig that whou'd, s's smaclesk, chatf as, he had nokes beth shim lyon hadkey hendeas, cander aud the d
#
# iteration 3000, loss: 59.130262
# t darn in."Shis jurtar thene his marily him siof himsto homa tertound him the anlemed the brecl, sief, therl hord athes dos even buck able forrlasingarst abreathing the dict dight Iwar, aly, moonce, t
#
# iteration 4000, loss: 27.628305
# r his wouth it fanstorope and orch minh apsicten to she withou, be yimish riss of to dord in he, sheat rake Hid with hour restorimed low Gregor mecerikh thleevem anct and aly tiot, andoritime that ofe
#
# iteration 0, loss: 44.744516
# gr at cood, Dre of hoult, be nive ffrme wever in rack ofly dour that Sfom ny mugck or theit deyt to the trvealy har steme they his with theigh, afte teango, with it was t and there whel, mond of Thee
#
# iteration 1000, loss: 45.251991
# ng sthat. Ileand in Ther he fafle the facl as ghis jot thew "ay ho thend farm teritma the flight'ised the diante, n istre lades and to the fald and the peater and and one ho gat lighing the very, ther
#
# iteration 2000, loss: 45.507953
# ck in therr ghaught age astee halmy to her souiny qraik:l, themea dissmof ontoor and she snitely had someMk and onk, and homstacloy ant him. Whe o-ther to there Grege. Gregory his pafhen - hone wnocbe
#
# iteration 3000, loss: 58.336676
# lran as of move hir was the oucundly the curcidury, his sost iftontew at his breaging oned to be whithed Greger would beppuared or har tratting in the simped firmy it to that eapat llock. The door sig
#
# iteration 4000, loss: 27.332828
# nd. How to Gregor and te wordsacw aid for hallm
#  they bientrtaithan look himsilf mere and it they can bely shem forker ant mpatiof. Aarbo, pist kive, peryict from was mith and ceesed that he wifn the
#
# iteration 0, loss: 44.454853
# ckom her far to she for someangorive gow Mos, "Yemo ablits on the morsting a room wyoly as wxel whance'ted of whrien dy.
#
# at; harsed her fand whot, they lound ankent bew lang that them that d doon bel
#
# iteration 1000, loss: 44.077221
# kbunta for his erthan- with to stistel alions meplidntt the thin'ld us tore she did to geven a derry olly por, at was that no doonth the tilttokt one soud the extortopel it bida ofto the forger, thoun
#
# iteration 2000, loss: 45.560141
# t foo hem weation she caupes.
#
# "Gregor't sletthen him ay the siakly on whick out at aWane allofe, that had would, hive, Gregor'ckiese as, atrabned the mowive, hems. Hat hak had lyow shatefploy, but th
#
# iteration 3000, loss: 57.946066
# ce, mattles a horr there -reel. Ho atlusued afrea intt afremn ssnitssy ant to dear". Gret whith, whore. Gregor the rand home ovechisuld and to the simchom about anleded when undy walled his sather and
#
# iteration 4000, loss: 27.024735
# ne in this before ur this way hersund in while at Gregor and sistew againtors of light the varsed in that lefting rawh thoughtqupable toknid antoresert ac and his fashed room, an livele,.
#
# The worked
#
# iteration 0, loss: 44.298818
# ld gor the tur- badon to the cempartirach."
#
# "Som and she tacing lorjusa, anthin wond sisted to nomerBfinglI while forit roslyrs into it without deen, ssmeat of the that spearesed,, we for s southed -
#
# iteration 1000, loss: 43.178626
# vely heast rned non'tu a courd he heard cslena shack, Greger courd his anait, the quse that hadd afley the kit the mporn but ento no whiese, wing the list
# y, he was of negow, exung. Ind unvert. I's da
#
# iteration 2000, loss: 45.885038
# igss see as his head hes wo hid jomeny stome ". Sow whoul, bether homotly for in that har they hos sis ins one sime coulm had so kear and very hin brt.
#
#
# Lot'g takent stome aches ?ither therk, thoued
#
# iteration 3000, loss: 57.826614
# led, but comed wouf itts whelemeas earun the rareft, with Asstouthis roprea him himped it abaung while soot antend normssy sible him. Buthtuned the inglail ofrow siget up anduden the inuthet his owly
#
# iteration 4000, loss: 26.680707
# ch, ch" werew their ithing Gregor muing at Greesp aly ffiled ane veik tryost dlaw intore if the reaking and, butik in thes with the derd watine eromily, Gregortid Gregor'n and with a fitlwar than Greg
#
# iteration 0, loss: 44.277990
# rate, yoom I was herms they way, har und prevecter. Gregarased his annexsed, pleant o- tormittreptirn out that kest war. Stlanging antented offer a itto the camslaring but dis father pidst roum tha go
#
# iteration 1000, loss: 42.390124
# se nouth dreath the fair agat all that ho stive if would rows nonich that was muth clear bedrwn the foubde the day now noidrM th the wey Wive comb hid to ne all onting and he thot ly tle lard tre takd
#
# iteration 2000, loss: 46.204034
# cr it ana sear", he coopeamay, as she had the lotkert mo the waSe a kpot becarentcough, Gregor chang the chief clerk!"
# B(tope mure it was nithong with thene wother to atan worew lonter thinges he hald
#
# iteration 3000, loss: 57.717012
# led of spethoughe handly tueve the risint, worec im anther hoon if, had his sthango shapled reace has aymist, ot norward comptine had were that whele slieked igralf oreefr. Gregor traweh down dfarly b
#
# iteration 4000, loss: 26.235052
# ly, appeasin to the randy stood and to the risterst shied a praying and ploking they the kivere rmind get levtremother for tout dookine say from they had agoud. stem gund as at iever, unay out his mis
#
# iteration 0, loss: 43.725637
# s ie bett for and ismabling and conay in their beng and Gregor's raws, mideang, she cleangre adso they haw they her fares moraining theim brt. And And's with him.
# I, ald, and she sthat of yerelt bedin
#
# iteration 1000, loss: 41.589468
# nteding, Gregor. Le cuire wayin's father tur" in her himself otto ghion, ortont sprean shisp, chisget uresking himself hishly grey turneversentlont and the tip to the floot as all the chief clerk, his
#
# iteration 2000, loss: 46.258614
# ve his mot eent had Igethe
# M was ans ersied hawh chome had then - on's mind that when he even ord his sister withem righter when he rommerient some bank lonmer she wnelevatcom, explive of a had noadin
#
# iteration 3000, loss: 57.787491
# le, stard's shist Hisupp as the pork har faclrom lyise if the mord a of hiqus his byeading ulrall couthing as the donr inthone but she simply intowhatr?"He was beck butingh and tainlings bro- him byof
#
# iteration 4000, loss: 25.598570
#  in, and he tack as untilith thwing enterding aid the ofter beed times farter to looking atyer at the waycs of clevibuse minever sithing elome ank, without hem the dillid them agoroperver though hows,
#
# iteration 0, loss: 42.426653
# nd graith, hers. Mas nead bust in then's leakeds they his temisiently bremened seeved monePss moch nommo the juss unterd, whil me corst and fathed firm they her poot sorning lood, where he he losting
#
# iteration 1000, loss: 40.337588
# nslmsst. He racl innound, that courdn't was the lack in,orc" had popenceve time wim. Uaid of the lext in tomegom arains. It the donghing; into the can hut oncain". Sulr Gresenth The fhen to give yom l
#
# iteration 2000, loss: 45.989629
# crecaling wat them. Slmonw his wistnovod, a d in way her, toltully onl of the three her had jound Gregor's sammisest latd.
#
# Ate has motter decain to wet and the mork hem his disher hunh buthrren anawb
#
# iteration 3000, loss: 58.362282
# cwes Gregor as if homongark; "She couldedby so sight would allayly sulled to his pomully an them the would lorvally now anxt indo w ismldionss conhar'myed to cospt shinwert, avirend for alm,'ble'thy w
#
# iteration 4000, loss: 24.801361
# b. Tone estels. Dt wnolghe had toked aing rad they deerid yory Jistle gor they his vaiced it doon wither welled to dear of then other fored theck her with his fragint un he winllaing blown, shiik with
#
# iteration 0, loss: 40.902723
# msiad wher?, gas sfamprefiteross.
# "Thing he care the floor cleably blontibat of bous of Gre. Som the guntine out as iff was then oven whother ssarjupay! weat they to the chace. Ye ceather theed did no
#
# iteration 1000, loss: 39.058734
# st he did. Theice slear reepreaunsiops. He segat he teathen(, that hadd pitse from the bit bedorm sisters. He telf there kerplewiss. tWing the than sche surcing at. Gregodt agroplaraby an to ker the p
#
# iteration 2000, loss: 45.447322
# ther't would have to get that I more an" his room and she cone yor a stor beraying it. Tway he could lagher. Gregor to ipt chanse, tears as mo him; nigisued the frookealy and loome sous rupsme s ent'r
#
# iteration 3000, loss: 59.054966
# rently neapine hourd loom,. The behtuce hats ay allawey for she on wiplome him, woole. Lother weut not har; the spoailly. as a grow Gregor crurss, suidey in striplly warned his parevuted his marese. B
#
# iteration 4000, loss: 24.180726
# t on the farthem erorised and pepparinges they was ded thrion flear. He was they at her haddn to ghing theyshe it salis this mother was sleapked unfiotentad, what head of the froit pingicu, I'm thay i
#
# iteration 0, loss: 39.566434
# lmost farss she cemt dast megct. I't gead, Bo at in frre ougut her. Ts they wish d have, modey kook wirhed eveungerle,
# ikse for the with drovine, hid omen Gretagine Gregor as dreabghter. "he to cruta
#
# iteration 1000, loss: 38.247049
# de, had no momether as if weat he had no dinest had thought over the kan. pacing his baint of the down thempest from his doonbo, and blfe the keat. Lut with his headt but if were asphe tarielthr" hama
#
# iteration 2000, loss: 44.929895
# uged bether blend colley theic leaviseadily in tor, abe in, him; byong! Gregor's motcen leich. The from the kighthe for had exon veay, "ad the varesming enfore she live that m't yould streer he would
#
# iteration 3000, loss: 58.778894
# ley an the voor smot in the pry he and aimutrawmo vere inly inls imen leff comhansen other the door. She would forvered sioter; noor amagned, she was ddenstine sealpthinghed taint would noticred hid n
#
# iteration 4000, loss: 23.914948
# nd whether sursk of Gregor'ske sfreas a ding, (oust hiveryea, begome though draime. No though the mindow and dly chere ard and not lark, whils wipl here to bul!k.
#
# He wincound him what, stry, and we't
#
# iteration 0, loss: 38.941508
# t with that te cound no wirkn  noudg saldiny ot mere nitesiop. At fer t il cor tomp his all ment""It would shew it samarest ladent butad wirh,, they rathing in ond and gut ction to whthis heat in cher
#
# iteration 1000, loss: 38.165856
# tg; thmy whes would dimokt this terwar. no asmot wnow himself and frray on the ckeich fexts sshe farAy have thrigg them could now have the kit this moont and where they could he could gave thes wer. M
#
# iteration 2000, loss: 44.387716
# rtessed aboutsarfessnom. But was somponge themm have anaine surers the dround, and whaten the other and oplnes, any he what she was roomme his asound ally'ly undo to leave at for the ver there me igzt
#
# iteration 3000, loss: 57.917137
# lly brotsemtete, rrite in fremed to it; ppretshing cime coot in ho; hand unly, his door was a quirm with indarbuck his preppayed in that chan son she form there un hoth a shary irmaney. The hample, th
#
# iteration 4000, loss: 23.590170
# rd fallid to dly wIythere qunted to had had been beand ulpory und mever tokebreBbaing ort're ho mighted not there halps, which mack. Nefbef yhe thad in the kiakt, On wert bo mirss that bester and that
#
# iteration 0, loss: 38.500378
# nd Gregor to be seiched hinj wean p-antious.ing to the faom nawoke anyulove anj of har, was swimat as they had the doow in,o buct of her olo- Seaver as if their brot bugstita, shey deanger's, they the
#
# iteration 1000, loss: 38.832634
# wayt this; he fout uin lorg. The fly fas alse fermet ssise ug the floor. This, youching it tous sees ig, toik. He saik. J hime. Nation, laft, med. The thilgs the risms in to halt de wepe seme to spers
#
# iteration 2000, loss: 43.598227
# r eveny had for spearing in the fexhed fikner what theigh she stare ur notore. Ahan's ssaifitarars a rimus if coulde by and il that he had novemest stoon!"Groanged that there. Shis had bo Gregor sway,
#
# iteration 3000, loss: 57.139406
# lised. she silfto". FMre, the voor of dome yinengint any molt enclifule ronly from into she fanllcongrace mare, "fre. Sat he had beenurongar and would nothare floscute out age; ulre carmare fou stat i
#
# iteration 4000, loss: 23.772977
# ble't fresid reden untort her aly and, thind hermew that had noted, had aspea there it'on he, satPe lingled at them and toleny shear Anth of and the wastin in in where of his heck and them rot had tel
#
# iteration 0, loss: 39.319847
# ok, the chester ib that N he tad id ablurk again they seadios, sheefll buciome vime owe trett; "hus was norien of her not ennelfughing op tofore" with thet klo got they sweld bock of hid lightret out
#
# iteration 1000, loss: 38.960414
# lles; the chief clerk. "Greaull. coud" the chief, would now surntorgwhat sis;, aHtuping un wert bren theme the kay wherp caured out and ble he thus ever the dowed; the way layk us beers no vount thim
#
# iteration 2000, loss: 42.887675
# rres. As where."
# Fhanab. Whe chievory chimonly towaw, alk that Gregor'g mether was woile had turne were misings un the mad any worke; purhed however. Shere womlew, st would in weres Gregor, migh prace
#
# iteration 3000, loss: 57.821974
# lly warch she wamen inta bytill bying, then?
# "Jot rase his hopec and ablust to hamp.
#
# Grete had har. Gretiol avoritied, hraich his salf concained buth, yon't the when chest of ble, trow have complise
#
# iteration 4000, loss: 23.429901
# ltoy. She trusk litely have been dround any frimuld. The thied them dist dopesied.
# The tood them could buing anyittoftald the tood ham and in the miakt Gregor callir romout thise quite the failed and
#
# iteration 0, loss: 40.599942
# s if antee that I wos gorn with liftent. Yhe chief in confa gascidiouss about of it, Iving "an they bewn the faly parely the tory meant, on they Gregor stiather tuat them lemen soon exelly bud berams.
#
# iteration 1000, loss: 38.027107
# yed the kcatce promend". Iet us cquerthon's letten, opre doinve she wask his ean the coulong, jotter", inne dabo incaliI liden from und to that deack his tiants as a latel, surs in her part bo but his
#
# iteration 2000, loss: 41.411239
# wlyar fur in one of and Onendeftoug hard herwin. Some ubed thethow you have her the same enturuive it a moung; how go that so meat. Ackeevly encouheral Gregar's somend, astermoQa plewings that illed a
#
# iteration 3000, loss: 57.937955
# le lous from the ellrxanss hoor for wothing down oneasur tood rightsuviegre strak would blispaling from too' come ane fort lfom hil? Gregor flecs; hurne himptive than d open ither dair brte, but to st
#
# iteration 4000, loss: 22.919509
# lly meat anteadty mintla,.
#
# The itoon and the clisiot to twatterew without deacheres them orened to the trome at the riodor agous and then his reamind. This shat all the ploke trat all they hey back h
#
# iteration 0, loss: 39.317957
# lly digh couch had thetidg, and was buck in. Igangomenn, but lof.
#
# BIt. Sjen us thing it was nivingist, wret was in herral and ganted the most barkned was almow you Grege Greains ind, but they fally s
#
# iteration 1000, loss: 36.369771
# ng they couct on they as strakght, was, his sight and the plock to the tabe no monot ab the rimalto that was over the chief clerk t thright. The wimst on that this tound no upuight fith jome noppomain
#
# iteration 2000, loss: 41.226149
# nce ollope at age throom brend too. Vreatod thenm oC and so getreing, as her han away inkeiver of ant pain,. she brarwing extribulin's iffod ope comn sitief onecone.
#
#
# Yway evound it went ifmorien ear
#
# iteration 3000, loss: 59.542362
# lly, gheir litecs comm urhed the diowinncknack brown arneall not with hos worling himselfece bying enothing; ", pright. There whire worventwoundentichan as his cister adles from a grabace her ty you s
#
# iteration 4000, loss: 22.933671
# y,, the kures. Sis benole, which he was from dy. Ind not hakd of whith if the way ababed to thall ofn had corminived the tamper aith had as them aupround, whele. Night afal mown ifteg the shout enewor
# iteration 0, loss: 39.426882
# n tige marither, wece sammed and bel - kicatly could bad.
#
# Wertush, chising down of hem. Had felm ganat suckemer toway even to get ores;.
#
# Wstod br. Sacmeger what they had steak becomane it whele thei
#
# iteration 1000, loss: 35.448479
# ng to gef leep an the sidn
#  Gregor sppakt hiv sare he cames to her fanding, the clising wot there ffor hid to kte to dawible pace. Him lead of rmook hime no over in is, and to frare no and to cone cre
#
# iteration 2000, loss: 41.759690
# ir, peamily its peened up a littre sherngough as Gregor was forhin of hou;d to be oree away ele talk to even be it awly it, ever the though he without urwarss. Unto freal any coomse and becaminat tone
#
# iteration 3000, loss: 59.340685
# sn virushidl, kith atwend Gret was the wlolk full to game an the room with that he wazled his stinled wert solely able to hame by wlenged outly on hereving nocailed allbant bach paretly and littlencou
#
# iteration 4000, loss: 24.090868
# ss; thenived ank atterted a reishl gents ather. He was sufrotted Gregor as thectored, while - he raid to like with stear as ataters andividy, they wastilass, whiles lingon. He quicther and gains their
#
# iteration 0, loss: 39.367614
# nd in he itanly biht wast thriag in his bist but noo gaid joly quite cas endey unfory would nownd outhad II atand be sbint was in whit wancid quther as they, was and mand his ase room wat up and Mspef
#
# iteration 1000, loss: 34.967718
# le, ploned had revor gast gas the jay,, as ofry thesp, the lect op nourde, to say and their trost acoupe he dad the kheir., the clevest as epesimuring unto the now rusted, yniikh them have tugned ther
#
# iteration 2000, loss: 41.573914
# ires thank smoked her Tisher with urls buictiy mole loxk apmonited, he soon coulvo lore, Gregor's rother and som, pearing a on the mobeton stay! and no wank of. I sure discines with the coveryth was;
#
# iteration 3000, loss: 59.750524
# lle. Grelly in wherofmed a mege. He had care by unxeght was somptaicred while Hit of his fremesn with ack his dralkess. It hee it of abl. who habb by when he soot as she samp. Qo wore qurtayed his fee
#
# iteration 4000, loss: 24.800257
# lt.
# "To the distwry they appeatingend and haddled us fremed them sask thit "Buss teltione alinet anout them which as he for urtarminly been they suredbsing them thim, begand and suld buck to the carme
#
# iteration 0, loss: 35.550168
# nd ts ne room at theif he came boon thought.
#
# Then had become fere all but cowny no geater ald that o- as their campeavious him on fiss wore it was Gregor wreted out of shems on a sagot rubly what sma
#
# iteration 1000, loss: 36.798657
# ny cuust of sumilf, cushed Mranst came it. The thre would juttiniseve his uister light that have set a lotgen's into tre closing indo mage held jour doid he frith afalled T- be to leved the nexs from
#
# iteration 2000, loss: 41.820609
# rley could ous anyorrely, as he looked hough foo dury some mack so that Gregor dowe'pe in unsendlyome sprely confer as if the kage inly bughten bectifedly then ho what's my not to the knex out asat as
#
# iteration 3000, loss: 58.664326
# lly, was the mawhat the thiokes and freseded, In alar where how yusit foued byen ase, all for to halp to himpaning, but there was forsally in, calling bath room There eaprons who preathee, harise um t
#
# iteration 4000, loss: 23.969082
# t, mull of shem it whole at there was ous afyertepon and empliter wantinet the risturned them and the ?idden aslightlockmy out of Gregor's petuned tometims in this room and Gregor's father their had b
#
# iteration 0, loss: 39.917494
# nd gound yound batil, did, that chathe thoughter who to ead astigitel.
#
# Nad.
# T"Mry, samman, muth nace had thor was at alle hardly ot be somewner mamhantent to frear of their jown thrighteiskry without
#
# iteration 1000, loss: 35.062061
# ps beain. His iem."
# Ar! Gress? I', rouns m drow any fleen the contlrnbugrond facleds, thoof with the door suok. ?D'slef weol. IYe sarn as in mad a swor that him would that the would happanedy ur eamit
#
# iteration 2000, loss: 40.315166
# ngeg his liowed awa they he while would she lotter whole she on the could litese, and he couldn teares: I'sais to hear of the kegt fornoun(os. Buch veayt to him the nown onturefting to whines as houre
#
# iteration 3000, loss: 58.668734
# lly of Grese have gromp the erenteding, therrofr to schand;rettins, but, have from his sister, if he wan wo have hamon a cprabe han she frrighld wars. But it., show trrew his wordy. Tunel of thot to b
#
# iteration 4000, loss: 23.640117
# lins. Non they wirhout, his eatiry - at his to ulot and sighed and the riom nley the risher the wastit -remot as expsair. He was able tonhter everyous, Gregor's dickir with she othording all the ushou
#
# iteration 0, loss: 40.191403
# n if, and fregothan thing soud, and go stelb ap Gregor tunned to to live that again them chore well one wele being maced in contre outstice all the morr was unleable wort nown him feec entir. And as e
#
# iteration 1000, loss: 34.270077
# ll ray able times. He would onve the ramm, "I take ho gaving alarm came bucinal cornons their to ga so maby the tab, clowith his fon teeth "Custed Mreshing himself yearss timesom tuart of dosisive; as
#
# iteration 2000, loss: 41.772652
# uce somethins, "ut youngeres, wht now dost rontible for only bosair a gest ither dother as against that his forse as the floive erestery hurrnith his sesfed to even thank nowed unto they had bolncon a
#
# iteration 3000, loss: 56.586095
# lly purra - things, abef his fatal and samition to craw strtong who whenone, had not or his prssadilarving harfach whereminth at all istha n there on themedening about his sister broundt howh ofhe had
#
# iteration 4000, loss: 22.893083
# t anyom. Tithing atyering at had through beent, lad Bengisaunicrmstaving it'o sidd, once, it opced to the whyem got all the madr willing oulil chamily, like forthad he was slick cound he mades the rio
#
# iteration 0, loss: 39.766219
# nce they mus more. Sim, and thougt", sambact low, brief must love of the cheedo near of his. Mrust mping thryec mare abango I to wo her corf in while they turned to came verpened albi"? over their dea
#
# iteration 1000, loss: 38.191914
# ry that the floor, I had wough, and that get with tof hare expor, Gregor natts I calle, voo thewe his weick would ssasked agently sot thoug, he lace meing food urates wopling the kay in", in have not
#
# iteration 2000, loss: 42.521093
# ngen begainf at anave yofe alaone Gregor's mother any as a room suthecceasly that, thencees; any ofrent from; as aheant anchis beccers one. Soubre soom, but them. The rege that bo noor, jus sowner wou
#
# iteration 3000, loss: 59.210020
# t have the come dyat been the oleort thes? Him tomethiegs to have hil for a lat. Wlre so grack brut of carmint herr ald, but cares pos. Goughrause, it mind goor ulway shally hore bath igre have was, h
#
# iteration 4000, loss: 23.483584
# s;; Ar waill rest doivioush that hild bewore it slikef or would oppontudeed to kitsp, wimht'sh as aftegled to his motthing her side,. Ye wast'aling arlyy that he saselt, and it as shat clear to his si
#
# iteration 0, loss: 38.634495
# lmost, "here even that his biot to meve boss on the toonoush was, Mrane op them and was comgontural of hil the soulkn about it, the two sometious Gregry in the pont, bust rilt us a flently him ulmest
#
# iteration 1000, loss: 36.454014
# lss too ca", into dud unne that wask hear have been cheening; Negore urtene a rites xsebont and letting atharsised siepering uping it was so stove had tece, door gassily, and dist rant. ", and uspitio
#
# iteration 2000, loss: 42.477960
# rwe from look heard him out of what even thouch plocked atain. I'mmak, she went that had his sister was, enour who exmecrate lrest so she said aboutsed of what at where thought siovenit lef pistaint o
#
# iteration 3000, loss: 60.743261
# liors and they cas for to havinivery him - hear away hic whice would not - if sthise, which would looked to iting, alsipredsain. I hearw he wovered not; interword if his abuet where geshang das his mo
#
# iteration 4000, loss: 26.182737
# y towned atleapbaraining -hewing mowh of waving thee nooned, they oy tropina rink to more ullone was one of that this eves garents theres. Mrying they was commonivel agout ur brew her agmined without
#
# iteration 0, loss: 40.553847
# sse, hay bot oper lastopangry could do reed the bect ond some juste Ms when however, they he just fas she reulh and pupecinay on the tomy ore in of fee hid hearyo, of aw of theic meqr tine on their so
#
# iteration 1000, loss: 36.329031
# nd he hear sadse, and no Ioun, whisp of the chief clerk the courfer, and comesbith cale as to clees. Fear fattins wnew, in's Gregor's rates some bespant ucaust j sevinass realoy lattent dictuagly whos
#
# iteration 2000, loss: 43.192320
# ire sleather'then kot to the kiproncered anstrow there woule yeresh.
#
# Wske first made so mecemst ans as he leanked the chestinl Olver mo-ded fuclused ony shat.
#
# "I Qneckle to even stoutch aso more ata
#
# iteration 3000, loss: 55.398369
# cu he that he was there as they was shat dome, year.,'s nutucetions whele herself room he banowhtreeving ther. The outside, hore boshis some could lave a bomta now wanted to hat'reing his his presstrr
#
# iteration 4000, loss: 22.454792
# cl, or the ruw his asay unly ully had her erent to the windle to the relilem und t mosty at.
#
# "Gregor, he make unso whyer getced to this wordd disibest streetsdomefint: about it withtorst to be condri
#
# iteration 0, loss: 40.272721
# nd bexomiving ovly but to erm. Phes headions duptien twhatible tay and westold ot their deckmsa by now he wand no sige kertabs fail lexpinte inticing for s roon sibe for the tage, caime. "Whation and
#
# iteration 1000, loss: 34.926814
# ng itterely become very one and just of dregent al sixte", plided. he leal yith his porms of dist on the bed any no boot ofer.
#
# SOatilw onco that felm his eres the vaising she came of the fistrong was
#
# iteration 2000, loss: 44.275477
# rte bne mound the e'fordemat frockiver the moce ine his fantly chan wotle that there. Yow had betod to lea,, he folled themprour away as quef, on to hear the ever thome conieaden so me that was should
#
# iteration 3000, loss: 57.364700
# lly mart now, drwamsien"", bryows avet, hear works of the worly have buind alllyushidry to him fours.
# I" was quile. Hrwat llet. Gracesedinise that there was statim;. "Whouch, anghis wanted to bicters,
#
# iteration 4000, loss: 23.019853
# ll one anve; to the timy known cal his pet and drifueche they apazed to had playted in this any unitalling becautiay. Utrestition and dose and plo ormobed they dupfied their disker to heard, soon deap
#
# iteration 0, loss: 38.304295
# lweaumbl out. Auring the cels, Ind oct of it was back but they feen that ban:s, and as edem the ineich, durning and the court, and to the terd and wedly every on the come and his coaryn goven sidre. "
#
# iteration 1000, loss: 33.144981
# ngh now intentid "Oeren someniing, (nd over bud all the day with ecl. he rister ut no lanm upen it sarent age ne phief ligrt, had a came the kgo morew", ster''ll pane in the flook hamon in affelt over
#
# iteration 2000, loss: 43.656558
# led on - alineded, and the keaking had food what therilg she squaring it was nnestwayed, ansen to him abato it whad bo ather he without dictuleconce ulleaso hore, asthers making out of itin any - here
#
# iteration 3000, loss: 54.795846
# slite, bain, himh.
#  Gregor almost hopsay what n with a of had saw the door. she wall asselrel he had through he had for him, now had for quartunututhing, had needed to had been anly urenution in d an
#
# iteration 4000, loss: 24.674819
# s and sllew theme aplees. Thiond suckighthinn lly Induned sive qudging allous and with hid urded to therper a netrielf on atread come intcrear intonted his comsainut for her had in the vemain alay wit
#
# iteration 0, loss: 36.486426
# w they, now the three as and buch of it let It was necom.
#
# atter ansilt was peace to get ore, then if whre they deat for their went ont, all the tire.
#
# Thing read be the gindoft fremet with it deary t
#
# iteration 1000, loss: 35.853794
# int, what kep ghise, up and dech as even wnot was not as a lert, ole, ard inconved. Gregor smoptingls, was, hich sam. AlleblaingM aly the fact br fouch again, "I his way reen cerrieg it richime the th
#
# iteration 2000, loss: 42.497347
# ll ghemed have were ouf of cont-re to shyer his sides and me last altoou left it. Ichel rearing to Gregor gond ouch back and colsobe -lyos and or!; lest so noging and comment and monet be seep."
# Buthe
#
# iteration 3000, loss: 53.170801
# ticed it waupled and lay and now therever sout there. Shat were but she had winlder of thim, but which, of slews but she would his without drie a most of the lomentedun.
#
# Hhatencharser lefthing with h
#
# iteration 4000, loss: 24.830977
# y of counisy it was nockesarying."Thind of Gregor, he wash of her, with a tit to chouthed to to lode without miofing anther out on to helt on dething Gregor's did of the tom anlsaly sit his reckoutune
#
# iteration 0, loss: 34.879154
# sked it tile. All intayt hersey had leat on yomited that was for as if the three bedint beid and his fame threw bfieg,, was a clocreasu as as for the ilmestive as if for hon he rust must get in askigh
#
# iteration 1000, loss: 30.389404
# y looked, prover do-f in track it was so that mosting. Fom her said that he roundby quether taoksa; had and said Gregesem the bed as and ngatth who.
# ", them, net fok the didd berarbasly buch may he at
#
# iteration 2000, loss: 45.471502
# t enoured any remplow. As when would sleaking the meat, although.
#
# In there when soundefone Itward come simily ss take asaze stratget. at reathing always outstration and then his father and boly, any
#
# iteration 3000, loss: 55.344111
# stclin he had dister had to stave him and she bedort the edeving would his parsiay, of the diod wonking onto the worr. "ou to tlyed it trotting round. Torh purtuld ofter than she on!o tuarious whin mo
#
# iteration 4000, loss: 20.867813
# blutedef abory diding as if Se day. Tne maye on chuer of reeging eapsing to, attermes coined actuakchor and seemed them with of the three, Gregen's bealding "Hounstersations spickncaramel thing ney. H
#
# iteration 0, loss: 36.163109
# s as a with Gregor, fuant payt. Fr. the loct as they in a the to spees in his worat sas unta room ur to the way fur mouin, nos, dackived him any, sut were to greef any, had that indreption of them wit
#
# iteration 1000, loss: 36.563179
# inw, spee, that he wis go baik: this s." iffort them to dr spoccusioffirelhed his pook aluast brobe one tise of tipnt in a prowny in the day, in urd of the fores ovemathe threagtitally sadg?, not was
#
# iteration 2000, loss: 43.249864
# nse jore ictomemil that whing show that while undone in for him. I way, his paterus that haw, puther about in s ol. And the jack onto askering. If lookes and couldn't strepwen rostunte there shat's wa
#
# iteration 3000, loss: 53.691226
# sly in the samo other thingh.
#  his sister, where his sister agouglt into treve.ly of his daif.
#
# The wincaited all his stsan withabope how had that Gregor his breat; pot., that she his near litechon fo
#
# iteration 4000, loss: 21.762220
# ltiops his sose tereaby ertyy to let of and thered it sare : towicluouce exhed apme forinted and yickiving hermevivery as one to reigh what of her into the rase made fis anthoutentavione had before di
#
# iteration 0, loss: 33.342059
# s effoct mone as zakned a moakd all whents jvessibly.
#
# ...
#
# iteration 0, loss: 40.123578
# s im it was enen too bid than cGrsctions, shrewted her, weie. They althat wimh now they? Then left tother shan into one of her, as on thes. was in her dresm groting out of forg strucked serious sound
#
# iteration 1000, loss: 35.052483
# tions fold that "filing say almomd he almortu;ulaker became stiling up"ane persaeml scind as he said, Andipascind that was disamploned them, flothert Gregor, and it strike from nound more than "ell in
#
# iteration 2000, loss: 46.412680
# cke in him fusing any mook he had ener. Faks notien up foot almose for her the each. He help he could smuch!e omen alarmem looked regly he s ater as his veakie -usheress which he was come in the flatr
#
# iteration 3000, loss: 52.762009
# lly wan on the ground mu had to br the gracces of waterifemblly full shufbed mother intwan - andow; Gregor swoppent wanted to semmable round had along oneruations was soon unjose the coust might and h
#
# iteration 4000, loss: 18.885338
# lie almovine tigo." Nope upr. Bniting, it in tis afaane without of acnuting vart- bromem brokgharving vis body with anxor no work becade; bring nolking; toward, Gregor and and Gregor's mishing evening
# iteration 0, loss: 34.011149
# gqueccuate sat a long. Wes oun bent doonst of forny we tulp nitht of then, behn donet in a sereat out they were beminct screamed qonathon morn could sqow what to from heray. An. TWs. to the gind or fa
#
# iteration 1000, loss: 36.399725
# wv, that meqings and was possible with the othorss the dect, "uribd and whilf with them in their innd with the key? And be secticing.
#
# He really nocking at the wall full furing there quirtle fulling w
#
# iteration 2000, loss: 43.414618
# nge in his footherso go them simpettniski" he had movemes for wish if sereared him to cutse his foom -rond vony itto She lithsso even long of his fist. "W he mould remaintlm should hurried to herself
#
# iteration 3000, loss: 56.348345
# lling in a ways; wake the door on her that she kuft in his chise close toway! or straight by tien his wiff was even the time out from , oreered at than it with his waye him his two nowed be near alrou
#
# iteration 4000, loss: 20.708853
# nr. Oreftre. Tregorb said yittanded at Gregor's tise, juin them had enderioasly. The tickhwereas runt diding a wept as he listening into the Gare, in a sime and little while Gregor hisw his fwom the c
#
# iteration 0, loss: 35.696607
# nd sometif suaran how were smosi, as to times ove with a wirm mus frem out on Gregor's back fusly then destering vercage to get fon y came der anter in their behind of tueith and Mr.?S Gregor undewing
#
# iteration 1000, loss: 38.228639
# tsone of her drushed in behan to do the jant held ke decaintenel abe sisted be abe mading things,.y, they?", the chief cormedse nodd. He spent. ", herself, could he caing, wouldn't on throb himself fi
#
# iteration 2000, loss: 51.148983
# ir, he about of anx carried some he then, he had gok even himself uppediately.
#
# Then should happened out of her his injooved from his foot as that from a grearly hargen everydmly nooked iw atst all th
#
# iteration 3000, loss: 53.656520
# dly with their him was hoarded was the chear them explarmant comlunie anore; the worknes she would be neesstated and playyer, his workhe, pact on.
# Snow"please on his presed would come bate op them had
#
# iteration 4000, loss: 18.700474
# er prevent again. Phe chair, antone praymabl him fewin. Hitwied bith wGre. Simply, asked him sere ard it wa leave sife its anyone diouin. Hed aviiudr and, their will, dil claning their moreffide althy
#
# iteration 0, loss: 34.369623
# sked the flat they were now that he sssathen and they self of the best goment her entabed, when the next became good of s ders strenger on her continue or the herd and she the thought away; and qour t
#
# iteration 1000, loss: 33.766374
# nd himself us ig they plaspif, that still care that was and with time; Gregor off in strented the threaw" did bace that he was a were not know was full this ig the muin they sursi that it gest behan -
#
# iteration 2000, loss: 46.082040
# nwo wooked wa the orcercusers - that had mod off on he of course, she window what he had they wene been go the conversess of if he would kes, norme he would shued there weme nother to only undoon no h
#
# iteration 3000, loss: 58.120841
# thing about the ,itht, had been regpe ds bitely, If his both again a better about his fnoc at whes was held words; his ownworg word parg ug;; though, of carefugiviog to gres abour the courh. Ind the t
#
# iteration 4000, loss: 19.379752
# ll at lictrd his injury behan to this room in the ground in the lirkher't it. Gregor whole. Gregor the nitht ker.ay, his reporing him and making hicroing un inner them?ar doing but mo-emeling and siid
#
# iteration 0, loss: 33.112012
#  stide a was storm, been comen so they took out of the room thin they disturked. Widrofron he could not, even smmeing. The turned senterm whether eventne than were gentern moongs and undepron out ente
#
# iteration 1000, loss: 32.573853
# nds of the chee teldn of e floigr of them seewed to dakr the chrefus surpice him, always rase w?icked up the table.
# "Mo the nobisten, was far of cout; mwist was nith to sive; The floor. "ereasnoy wast
#
# iteration 2000, loss: 45.099837
# nger his sister had thrisstes in for mancching hot with his sister's mestly whthaves so sen ontt it was more, comfortunate, he could go that Grawer. Shemabed unkinissige the fornest especiance at lict
#
# iteration 3000, loss: 57.957496
#  impangenth hit lower his beccmse of; his mostring herributing and whurhow his father; grome onto a dryin be haire; who he'r by yeck, but it was out he could really gane hiops not immobiing us aw home
#
# iteration 4000, loss: 22.522295
# er had beyoutring and plewsetno-ressat its ktarked to the windy Gregor's nat be hairs of them asseevely. Gregor's botyes and without on his room and more. They builed, and inting bping too Snrenved, t
#
# iteration 0, loss: 33.620651
# bout their she had been do nove in front of her comple oft mound iv for the fust rentospient might twered the first commant one of their was strengthan worns apore stand, close!ce the conserved her fo
#
# iteration 1000, loss: 35.300709
# nwone she found - lasping and, in bock came in, herst, throsg of her left to then, slippan on the family carefuling that he was no duraili ake did ighisimist geptle,, git rrosainne his drand the flan.
#
# iteration 2000, loss: 48.440803
# mbe thank astention. Is something from where she moved he awsush of his mollowise. Gregor'she had somewhere, from her came carrieus and they furnhur to hear chething should thought.
#
# A"
#
# kInot, it wau
#
# iteration 3000, loss: 56.466270
# lly, whom a belay, difficully usld inting, and he had not his sister; surprese on tip-t subluel ab all, but wern hus inabining surd; "Whavper them careful espicted or the room.
# The smokimu in they for
#
# iteration 4000, loss: 20.664283
# r. Things Ilacking Gregor and it another had eifhcluing any closed her, catching in hir rending, had been a neading outhing noteler conningcry, and this way in the monionert nover so go in toing they
#
# iteration 0, loss: 34.819808
# nd from the stamped out: the tried Gregor in the trandend but, where they de could not too, jush his end vertee to enee thrus mentib him. We tusseble nownent, with memp warm prit bace a broom or pornt
#
# iteration 1000, loss: 36.652007
# gly and seemed could nawe, from the next remained their vead nothing e forgets, youtring, into hudding? "Lhe have reallfing, as they look rught over the unpidieg one sampled he was using!,, wepe, anyt
#
# iteration 2000, loss: 42.187200
# ir. Nriting his sister was shone of his where he mave lrkng everywhed thak his father, on his mighenserfoure -ome of co might of his bisistichvest be nighing as he could uived.
#
# Gregor's mother, stren
#
# iteration 3000, loss: 49.795015
# limen brite in there. Sit their why exhapiry was disturreat, har abnut he warked unner pisiorsed.
#
# Hrotwer probably uighcer, with ghe wan. Woo his brensed Gregor two though, but had begore, he requgiv
#
# iteration 4000, loss: 19.756744
# ll nid there were were allman things.
#
# Thithly and finished his harding; his;vead., "id" his sother now the woyte somewinhile, with hurriedly himself betine it was not beeaining. The furniourreation a
#
# iteration 0, loss: 31.002700
# nd it were csile enqism, And he had been seleation when the money the other was n coust for the beded to pey hus can curry soon had the face in michl swould remained there was been rented her in she c
#
# iteration 1000, loss: 35.521790
# t c le plock to him hem try to  of the go the fusucr from y jndoss wouldn't do im about the fegche that they celland in the lect. He no in as in centriend him tears, at the n!wer fice of the bed - his
#
# iteration 2000, loss: 42.014049
# rwoman him hoardees than his hand.
#
# IS Gregor ain her to her him had in motthr part couldn't weep of it. Hnick of it his injurress him them had unilong a mistore atting.
#
# T- his fisher had him kcat wh
#
# iteration 3000, loss: 56.471223
# untoughed if word in his breasfioully, make his mother wantest for him diff romp, leepirg at the evening on the maib aware his nothing about ut fame buthing at all up tiwe on ald the ceey himself br.a
#
# iteration 4000, loss: 20.211950
# e, it way only nesting at all, them anning, better any roomst thinkrever and mertown first need itto the violining, bring thathwhat they. Tregor., recenation wasnortanichtent Gregor had been indiswor
#
# iteration 0, loss: 35.962092
# t the concentroom and leave would almost bedevel then what now to kem turned once moment been ant going up to goo seemedy but wert the smens, would owed down worm. Mr. Samsa, shumn foo seemed but this
#
# iteration 1000, loss: 34.959619
# ge?"
#
# "The from it, as chatger to make of the key?, askreamo thiskcanve thet in her faile Gregor's regort now?" "seven ned then all these Gresed a from Mrawer like a there wesp! didugh,, he sat him do
#
# iteration 2000, loss: 36.521280
# cker to the sarewtion the moor sigirny she would slowly asked them in theme he would staakely; they leacly from the room witr eher ha fretess worly askiously if he could stay happener. Ohe use. bunghe
#
# iteration 3000, loss: 64.287479
# untile, this way out again, any hardmy to have byough, anywup. Gaict it chaite,, helling outled, himself batthrwares;ly, whatever usfore his injudied even thought of buttoett, gothus again carryed not
#
# iteration 4000, loss: 18.499633
# rr any, withour mide the right again Grenuwing, he had tine ertabciagion from ainf of it betam or clakeinitation their baw, but the incleas. Weld, But there anso mish, or especially. Gregor anxwaying
#
# iteration 0, loss: 38.253322
# nn tilen outsincest that was,'re, Mun shee sodernso now ngister, shinting gone with ever thought of him theer aid holds for her becamsemening in menting to doy's tees thought of mixtanion in mottle wi
#
# iteration 1000, loss: 32.546744
# ter, "gen that nother, the kivero- was go,.,
# "Thought camesuwa", haprening than she had no door and off it! and sometwing that would untilet of it, be here unveartay, and broke in it!r must surHing ni
#
# iteration 2000, loss: 45.964052
# nge stoming on his mothen on the hadghted. Utice back of the- sleve. Gunter would tother, worked, kook moued his fios, him brew which whimp so thave the epenings so than.
# "Bu Gare him;ln hab there liv
#
# iteration 3000, loss: 57.109588
# lld it was Gregor cquad omer to get his eyew happening who, y on omerathone. He gegl chuic arming him and then? It would onto o had been empucration, who were was alreedy he way whil lard unuth there
#
# iteration 4000, loss: 19.261745
# tran; !atigh. before his room and Gregor. Wither back in my houed, abled.
#
# ed his righting back in thiik of attention., remaiarable? ith mid himlencis and vistone, it was gitt in beda sorn noticed his
#
# iteration 0, loss: 31.714005
# s s moment, they would be nex push to himbeciy acqung would hal, back and dresk Gregor could just or them unregated on them hudghen duw was inned they he wust. Sou three ged, her or a siid hurrying th
#
# iteration 1000, loss: 34.740317
# ps, and the charf mutching towards up, it comilise the while from the tamp of let the slightest, the floor. That's of ald towarks. Gnewent himself the day, chate his mouthture, the kottro he's was nou
#
# iteration 2000, loss: 45.978749
# nce uncerleasly soon to force of the for mire had his farticiled to her hathef It was sheet and susked unker though, Mhe's so stood whole his father could not comeringsicves hell his fretsee showe for
#
# iteration 3000, loss: 63.649305
# ll and would have exply hard under he had alsayb pushele with the room some way for hely, at chatcem in the was or to the mood entielly looking a friet.
#
# SGregor shought out cho were beer two the sigh
#
# iteration 4000, loss: 17.539863
# re. He was and immestancining thing hir and Grot way his room. Ne wouldn't kigay things in hera bernaning their needings his right kit onter a lirt there was still being, Wide and stood up disteren st
#
# iteration 0, loss: 33.544132
# ssed, uppeeef, "st't the flothes would one and the bear was furtincs ine one which not they aw they always from then sice and they were closed " at all go and inconntoos under a stentingers, Me conngr
#
# iteration 1000, loss: 37.340095
# gs. "Aemperm.
#
# Gregor chanings almost a diss on. Yid nnidill filaly nges you was no kemis, one that consers, as hersilv from the chief clerk, waite und this ctister had his head offer the floor, was s
#
# iteration 2000, loss: 45.773764
# s every even noking his ulder from the others. It with unew that hisseef somet even gononted the little mubbing alrishe shouted, and might handifulak when his mother anown it with his head weaking the
#
# iteration 3000, loss: 54.189122
# tionche his prespart. His parents agai around than lark, of it. Have impepiance was carefrhing when" he came into his straight it, alany would stay unulowg and he was f on empoysecked, at the walk out
#
# iteration 4000, loss: 19.326683
# uring falling they brrents and diswmangway. When his bocauned in amwant, Gregor and fortune all dostichleing they knew,y and it was more ontobdens by Gregor's rooning their sailss buhing his eytouthed
#
# iteration 0, loss: 33.046546
# wsy, where Gregor then junger out for he culled much street ffinated sight not they did not be rentied bust sechiter all grugation than y notice was an animal out of it if the other awcker. The create
#
# iteration 1000, loss: 27.796474
# pfoy unvils, and there, did not distived himself up and that he dod finself there,, he had hale, pliffy "now the roin was not fought, and jry, he had no quight was swirtstatevanon,, satce,, whocred un
#
# iteration 2000, loss: 45.575603
# ir. Grewor's mother him. Beaved as more. It wast'ry shuck in sermom notice room with a where whilf he frome askious. Gregor's sisner kister stayed let momer. But it wentor, he said a what's wherever -
#
# iteration 3000, loss: 58.325448
# lly and his stretched in beding the whine, howe slowly, wouldrefule for a whilen enougrb of any olley.
#
# hose off, but, him. Hagh had on the furnir into his room with his haid anx prestare and would be
#
# iteration 4000, loss: 22.265693
# er. Hiils; for the shied aftertain. He bant would no beew forward, with him without veouing whichrear state again in theyr gothing high mindbed anying this air"ision, he heard, they under the armonciv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-277-2c0cd9002f41> in <module>()
#      19         # fp, bp and update
#      20         ys_pred = rnn.forward_prop(xs)
# ---> 21         gradients = rnn.backward_prop(ys, ys_pred)
#      22         rnn.apply_gradients(gradients, learning_rate)
#      23
#
# <ipython-input-266-9375f699b7f0> in backward_prop_routine(self, ys, ys_pred)
#      51     for t in range(N):
#      52         dz_t[t] = (1 - np.power(hs[t],2)) * dh_t[t]
# ---> 53         dW_xh += np.dot(xs[t].T, dz_t[t])
#      54         dW_hh += np.dot(hs[t-1].T, dz_t[t])
#      55         db_h += dz_t[t]
#
# KeyboardInterrupt:

# %% [markdown]
# Run the following cell to produce sentences using the trained RNN:

# %%
# kafka, including upper chars
for i in range(10):
    print('------ Sentence %i: ------' %i)
    print(rnn.sample('a', 200, char_to_onehot, chars))

# %% [markdown]
# Here are some generated sentences for reference how good the results should be. Not quite passing any spell checking program, but there are some real english words in there and the sentences seem to have a reasonable structure.
#
#     ------ Sentence 0: ------
#     ted eat aread noup, seed, but. ythed whithit tued that and in ask chemr tirme ble serpareing. he wionly memind. Dedteren drager, chat ther se stealeay. The kpay shir in wha dangereag he torearr ieve w
#     ------ Sentence 1: ------
#     swayly wase Mlamer io beell hom nofrreang, hr meed tould, Grere, werned coull gitr theQr coule verustengs at jeas whear', fasmer's, ad ho mofello goin "hey in normablite chas a) he. Heenew "thel seefr
#     ------ Sentence 2: ------
#     r's avethen harly dsundiigex; thinew, oug lertinestad to the wourd jhen sorywe, thever shene It, thour" hawss He:thon's batiar's sfin, luike he. Ar uver. Af. qanilew ucheed attricgwaynong roked t- an
#     ------ Sentence 3: ------
#     tor
#      unde, thab haw dtidtly kad sendeder, ithed far theme, veedlly nowlyin; and )rece thete disse, out louthe, row the rapeasterse at. Heed rnweem. "ut he bleitny Grerorot ie reryibe. So in., Hers ane
#     ------ Sentence 4: ------
#     ding, fitse. . Whisly andit, she haing "ya bistatily dlatkedor whing saded theust, but the stere stotady is eleaprcentake, got to mame luch ally, mus llablly, ach caling, at what, he want aar athen d'
#     ------ Sentence 5: ------
#     cll"end sat what herpingoth thouthar ald beinvaver.
#
#     Tere sreaned on in she was athar thatssu fres is at lees morther all sroaven to somichary mothtrey norytiot a tior sow bercead lassedore towist at
#     ------ Sentence 6: ------
#     gly.
#
#     Shen in shend comrie t oreth ubserwer he dist in commicherr. Wrmeathithemy nougracl.y'e sate horkllomisted betrnowhrous wfverthr bleatekeM tusinitedy Herach mop wislrocly theirse
#      on illy ans in
#     ------ Sentence 7: ------
#     dd, puting ot been ay theed . Hemula, he farer". The h hanor, and dandid to the sedertereveng untint.
#
#     Wken", surme ceared thet lomp io wotcouUir onsur"ont ar with, thancMmperny him., is sas bees coul
#     ------ Sentence 8: ------
#     d natmen", he theretotist wist, Gregely, arly re caule he praser, and woll buccem, then atse. Hemu haded ditince and dleyrist comply. "Vm inen beglings wet ou't dot, plest willay theren lipsest inpren
#     ------ Sentence 9: ------
#     byed Gregst oonsbecemed thet ad herladble, din ther, and at. Numferringtice st ead thelr way mors. Ium loomul themo head roon inf thet the. "lencorn was ned in tuc'e foot butimed, -feritn be thand Yun

# %% [markdown]
# You may try different learning rates, different number of neurons for the hidden state and try to prune the text from special characters and upper characters, but the fact is that this is only one single RNN cell and it is as good as it gets.

# %% [markdown]
# ## 2 Neural Machine Translation <a class="anchor" id="2"></a>
#
# In this task you will implement a small neural machine translator using the Keras API. The final model will be able to translate english sentences into spanish sentences. Unlike the previous task, the input and output at each time step will now represent an entire word instead of a character.
#
# The task is divided into two main sections:
#  * Pre processing of data
#  * Building a sequence-to-sequence RNN
#
# The principle of sequence-to-sequence modelling is shown in the figure below
# ![seq2seq unrolled](utils/images/seq2seq.png)
# In your case, an english sentence is input to the encoder network, one word at each time step. After the sentence has been fed, there will now be a representation of the entire sentence encoded into the hidden state of the RNN. The hidden state of the decoder network is thereafter initialized with this representation and tries to generate the sequence of spanish words from the initial hidden state.
#
# Run the cell below to import the necessary packages to get started with the task

# %%
import re
import numpy as np
import unidecode
from keras.preprocessing.sequence import pad_sequences
from utils.tests.ha2Tests import *
# Out:
# D:\Python\Anaconda\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### 2.1 Pre-processing <a class="anchor" id="2.1"></a>
# The dataset to use consists of bilingual sentence pairs. Each sentence in the list of english sentences has a corresponding spanish translation at the same index in the list of spanish sentences.
#
# Basic preprocessing has already been performed such as:
#  * to lower case
#  * remove any padded spaces at the start and end of the row (trim)
#  * convert from unicode character set to the ASCII character set. Example: á --> a and ñ --> n.
#  * If the character is a question mark, punctuation or exclamation mark: ? ! ., put a space to the left of the character to make the char into a separate word.
#  * remove any non-letter character
#  * split each line into a tuple, where the left element is the source language sentence and the right element is the target language sentence
#  * remove any sentence pair with number of words more than 5
#
# #### 2.1.1 Loading and inspecting the data set <a class="anchor" id="2.1.1"></a>
# Lets first load the english-spanish sentence pairs into memory and inspect some samples.

# %%
# load data set
lines = open('utils/spa.txt', 'r', encoding='UTF-8').read().strip().split('\n')
data = pickle.load( open( "utils/spa-preprocessed.pkl", "rb" ) )
spa, eng = data['spa'], data['eng']
SEQ_MAX_LEN = 5

print('There are %i sentence pairs' % len(lines))
print('The shortest english sentence is %i words' 
      % np.min(list(map(lambda line: len(line.split(' ')), eng))))
print('The shortest spanish sentence is %i words' 
      % np.min(list(map(lambda line: len(line.split(' ')), spa))))
print('The longest english sentence is %i words' 
      % np.max(list(map(lambda line: len(line.split(' ')), eng))))
print('The longest spanish sentence is %i words' 
      % np.max(list(map(lambda line: len(line.split(' ')), spa))))
print('\n10 Random short sentence pairs:')
for i in range(10):
    ix = np.random.choice(int(len(eng)))
    print(eng[ix],'\t',spa[ix])
# Out:
# There are 114282 sentence pairs
# The shortest english sentence is 2 words
# The shortest spanish sentence is 2 words
# The longest english sentence is 5 words
# The longest spanish sentence is 5 words
#
# 10 Random short sentence pairs:
# tom was hospitalized . 	 tom fue hospitalizado .
# he ruined my life . 	 el arruino mi vida .
# im grateful . 	 soy agradecida .
# dont sing . 	 no canten .
# they found him guilty . 	 lo encontraron culpable .
# i like your frankness . 	 me gusta su franqueza .
# were not in boston . 	 no estamos en boston .
# no one knew it . 	 nadie lo sabia .
# its not just that . 	 no solo es eso .
# dont leave them alone . 	 no los deje solos .

# %% [markdown]
# #### 2.1.4 Word-to-index and index-to-word conversions <a class="anchor" id="2.1.4"></a>
# Just like in Task 1 earlier, you need dictionaries to transform between (in this case) the words and unique number representations. The following dictionaries/lists are implemented:
#
#  * `eng_ix_to_word` - a python list where each index is a unique number that represents the english word stored as value.
#                       `eng_ix_to_word[0]` should equal to `ZERO`
#                       `enx_ix_to_word[-1]` (the last element) should equal to `UNK` (unknown)
#  * `eng_word_to_ix` - like `eng_ix_to_word` but reversed, a dictionary mapping every word into the unique number. The key is a word that also exists in `eng_ix_to_word` and the value is an integer, that matches the index of the word in `eng_ix_to_word`
#  * `spa_ix_to_word` - same principle as `eng_ix_to_word`, but from the vocabulary of `spa`
#                       `spa_ix_to_word[0]` should equal to `ZERO`
#                       `spa_ix_to_word[-1]` (the last element) should equal to `UNK` (unknown)
#  * `spa_word_to_ix` - same principle as `eng_word_to_ix`, but from the vocabulary of `spa`

# %%
eng_vocab = set([word for sentence in eng for word in sentence.split(' ')])
eng_ix_to_word = ['ZERO'] + list(eng_vocab) + ['UNK']
eng_word_to_ix =  { word: index for index, word in enumerate(eng_ix_to_word)}
spa_vocab = set([word for sentence in spa for word in sentence.split(' ')])
spa_ix_to_word = ['ZERO'] + list(spa_vocab) + ['UNK']
spa_word_to_ix =  { word: index for index, word in enumerate(spa_ix_to_word)}

# %% [markdown]
# Now we convert the words of `eng` and `spa` into their corresponding index numbers
#
# Run the cell below to initialize these variables:
#  * X - A list of sentences. Each sentence is represented by a list where the i'th element is the index number representing the i'th word in the sentence string.
#  * Y - same principle as `X`, but contains the converted spanish sentences
#
#  Example:
#  if `eng_word_to_ix` is defined as `{'good':0, 'morning':1}`
#  and `eng` is defined as `["good morning", "morning"]`
#  then `X` should result in `[[0,1],[1]]`

# %%
X = [ [eng_word_to_ix[word] for word in sentence.split(' ')] for sentence in eng]
Y = [ [spa_word_to_ix[word] for word in sentence.split(' ')] for sentence in spa]

# %% [markdown]
# #### 2.1.5 Padding <a class="anchor" id="2.1.5"></a>
# Since the sentences are of variable lengths, padding is needed to make every sentence equal length. Every sentence list in `X` and `Y` are padded with zeros to make every list equal to the length of the maximum sentence length. The zeros are **prepended** before the first word.
#
# Example:
# if `X` is defined as `[[1,2,3], [1,2], [1]]`
# then after applying padding, X is equal to `[[1,2,3], [0,1,2], [0,0,1]]`

# %%
X = pad_sequences(X, maxlen=SEQ_MAX_LEN, dtype='int32')
Y = pad_sequences(Y, maxlen=SEQ_MAX_LEN, dtype='int32')

# %% [markdown]
# #### 2.1.6 One-hot labels <a class="anchor" id="2.1.6"></a>
# The last pre processing converting the data into one-hot vectors.
#
# For this task, **only** the labels (spanish words) are going to be transformed into one-hot vectors. The data points of english words are only going to be transformed into their corresponding numeric values by `eng_word_to_ix` because `Embedding` from the keras API already implements converting the inputs to one-hot vectors.
#
# Transform `Y` to have the following properties:
#  * define `Y` as a numpy matrix of shape (number of sentences, number of words of longest sentence, one-hot vector length).
#  * dimension 0 represents each sentence (batch).
#  * dimension 1 represents each word in a sentece (padded with zeros for equal length)
#  * dimension 2 represents the one-hot vector for that particular word in that particular sentence. To pass the test, a onehot representation of word `1023` should be a zero vector with its 1023th index set to 1

# %%
# TODO: convert each index number in Y into its corresponding one-hot vector
num_output = len(spa_word_to_ix)
print("Tip: the shape of Y should be: (%i, %i, %i)" % (len(Y), len(Y[0]), num_output))

def Y_to_onehot(Y, num_output):
    # Complete function according to description above
    # YOUR CODE HERE

    onehot1 = np.zeros([len(Y), len(Y[0]), num_output])
    for i in range(len(Y)):
        for j in range(len(Y[0])):
            one = Y[i,j]
            onehot1[i,j,one] = 1
    return onehot1
# def get_one_hot(targets, nb_classes):
#     res = np.eye(nb_classes)[np.array(targets).reshape(-1)]
#     return res.reshape(list(targets.shape)+[nb_classes])        

# onehot = np.zeros((len(Y), len(Y[0]), num_output))
# print(onehot)
# m = np.matrix([[[1,2],[3,4]],[1,2],[3,4]])       
# m[0,0][0]
# Out:
# Tip: the shape of Y should be: (22947, 5, 8805)

# %% [markdown]
# Run the following cell to test your implementation.

# %%
# test case 
test_Y_to_onehot(Y_to_onehot)
# Out:
# test passed

# %% [markdown]
# When you passed the test, run the cell below to convert the sentences of Y into lists of onehot vectors

# %%
Y_onehot = Y_to_onehot(Y, num_output)

# %% [markdown]
# ### 2.2 Implementing a sequence-to-sequence model <a class="anchor" id="2.2"></a>
# In this section you will define, train and evaluate a sequence-to-sequence RNN architecture with the help of the Keras API.
#
# #### 2.2.1 Defining the architecture <a class="anchor" id="2.2.1"></a>
#
# Now you are going to define the architecture for the translator. There are several possible architectures for performing translation, which is a sequence-to-sequence task (an input sequence, the English sentence, mapped to an output sequence, the Spanish sentence). If you take inspiration from searching the internet, you might come across neural machine translators such as [Google's Neural Machine Translation System](http://tsong.me/blog/google-nmt/). This kind of deep architecture was trained for a week using 100 GPUs, which is completely out of reach for the purposes of this assignment. Instead we will ask you to implement a simpler architecture that, even though it doesn't possess all the important parts of a translation network, still performs acceptably.
#
# The architecture you are required to implement will closely resemble the image shown at the start of this task. First the input sequence is fed to an encoder network, which is in charge of summarizing the entire sequence in its internal memory. This internal memory is then fed to a decoder network, which uses this summarized content to produce the output sequence. Both the encoder and the decoder networks will be comprised of a single LSTM unit, with a memory cell of arbitrary dimension. Since we won't stack LSTM layers, this can be seen as a "toy" version of a complete LSTM architecure.
#
# #### Practical remarks
#
# Note that the input sequence for each training sentence is a vector with 5 elements, where each element corresponds to the number of that particular word in the vocabulary.
#
# Because similar word indexes don't correspond to similar words (e.g. index 133 corresponds to 'joke', whereas index 134 corresponds to 'silence'), it's easier to train our network if we map this data to a space where the semantic meaning of the word is related to its geometric position. For instance, we would like the word 'car' to be closer to the word 'bus' than it is to 'tree'. This can be accomplished with the `Embedding` layer module from Keras, which tries to find a suitable representation for positive integers in a higher-dimensional space by using dimensionality reduction techniques in the matrix of co-ocurrence statistics of our input data. This layer can use an already trained mapping (like Word2Vec), but in this exercise we'll train it ourselves.
#
# Besides deciding how to encode the input, there is another important practical remark to be done. Since the decoder network will also be implemented as an LSTM, it will require inputs. According to what was described earlier, the only important data for this network is the memory cell at each time-step. Unfortunately, there is no simple way to create an LSTM cell without inputs (you can, of course, customize the LSTM layer to not receive any inputs), so we'll simply feed zeros as input at each time-step and it's likely that the optimization procedure will tune the decoder weights to disregard this input eventually (because it's completely uncorrelated to the input and the label, so it doesn't help with the prediction at all).
#
# #### Keras tips
#
# - It's necessary to use the [Model class API](https://keras.io/models/model/) for implementing this model (because it has two inputs, the input sequence and the zeros to the decoder). Be sure to familiarize yourself with this way of defining models in Keras.
# - You can define an LSTM cell using the [LSTM layer](https://keras.io/layers/recurrent/#lstm).
# - The LSTM layer by default outputs only the output for the last time-step, which is great for the encoder part, since we don't care about its outputs anyway. However, for the decoder network we want the outputs at all time steps. To accomplish this, you can set the argument `return_sequences` to `True` when creating the LSTM layer.
# - You will need to feed the memory cell content of the encoder network at the last time-step to the decoder network. You can ask the LSTM layer to also output its memory cell contents by setting the `return_state` argument to `True` when creating the layer (this makes the LSTM layer output three things: the actual LSTM output and two variables with different parts of the LSTM internal memory cell).
# - You can specify the initial state of LSTM layers symbolically by calling them with the keyword argument  `initial_state`. The value of `initial_state` should be a tensor or list of tensors representing the initial state of the LSTM layer.
#
#
# Now, implement your sequence-to-sequence architecture in the function `create_model` by following the descriptions of the function.

# %%
# Add your import statements here
from keras import Input, Model
from keras.layers import Activation, TimeDistributed, Dense, RepeatVector, Embedding
from keras.layers.recurrent import LSTM
from keras.datasets import mnist
from keras.layers import Dense, LSTM
from keras.utils import to_categorical
from keras.models import Sequential
import spacy


def create_model(input_n, X_seq_len, output_n, Y_seq_len, hidden_dim, embedding_dim):
    """ Define a keras sequence-to-sequence model. 
    
    Arguments:
    input_n - integer, the number of inputs for the network (the length of a one-hot vector from `X`)
    X_seq_len - integer, the length of a sequence from `X`. Should be constant and you made sure by using padding
    output_n - integer, the number of outputs for the network (the length of a one-hot vector from `Y`)
    Y_seq_len - integer, the length of a sequence from `Y`. Should be constant and you made sure by using padding
    hidden_dim - integer, number of units in the LSTM's memory cell.
    embedding_dim - output dimension of the embedding layer.
    
    Returns:
    The compiled keras model
    
    """
    # Input and embedding layers
    encoder_input_layer = Input(shape=[X_seq_len])
    #print(Input(shape=[X_seq_len]))
    encoder_embedding_layer = Embedding(input_n, embedding_dim, input_length=X_seq_len, mask_zero=True)(encoder_input_layer)
    
    # Create the encoder LSTM.
    # YOUR CODE HERE
    encoder_LSTM1 = LSTM(units=hidden_dim,
                         return_state=True)
    encoder_output,hidden_state,cell_state = encoder_LSTM1(encoder_embedding_layer)
    encoder_state = [hidden_state,cell_state]
#     encoder_LSTM2 = LSTM(units=hidden_dim,
#                                      return_state=True,
#                          input_shape=(X_seq_len,input_n),
#                                      kernel_initializer='glorot_uniform')(encoder_LSTM1)
#     encoder_LSTM3 = LSTM(units=hidden_dim,
#                                      return_state=True,
#                          input_shape=(X_seq_len,input_n),
#                                      kernel_initializer='glorot_uniform')(encoder_LSTM2)
#     encoder_LSTM4 = LSTM(units=hidden_dim,
#                                      return_state=True,
#                          input_shape=(X_seq_len,input_n),
#                                      kernel_initializer='glorot_uniform')(encoder_LSTM3)
#     encoder_LSTM5 = LSTM(units=hidden_dim,
#                                      return_state=True,
#                          input_shape=(X_seq_len,input_n),
#                                      kernel_initializer='glorot_uniform')(encoder_LSTM4)
                    
    
                                         
                                    # input_shape=(X_seq_len,input_n),
    # Null input (should be fed with zeros) and repeating it the same number of times as there are words in the 
    # target sentence
    null_input = Input(shape=[1])
    repeated_null = RepeatVector(Y_seq_len)(null_input)
    
    # Create the decoder LSTM (feed it with the memory of the encoder network). Call it `decoder_layer`
    # YOUR CODE HERE
    decoder_LSTM = LSTM(units=hidden_dim,
                        return_state=True,
                        return_sequences=True)
    decoder_layer,hidden_layer1,cell_state1 = decoder_LSTM(repeated_null,initial_state=encoder_state)
    
    # Add a fully connected layer and a softmax to the outputs of the decoder
    decoder_fully_connected = TimeDistributed(Dense(output_n))(decoder_layer)
    decoder_softmax = Activation('softmax')(decoder_fully_connected)
    
    # Create final model and compile it
    model = Model([encoder_input_layer, null_input], decoder_softmax)
    
    # Compile the model. Use a loss function, optimizer, and metrics of your choice
    # YOUR CODE HERE
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    
    
    
    # Add these arguments to the model for convenience
    model.hidden_dim = hidden_dim
    model.embedding_dim = embedding_dim
    
    return model

# %% [markdown]
# #### 2.2.2 Training the model <a class="anchor" id="2.2.2"></a>
# Now create the model and train it. Try out different hyper-parameters if you're not satisfied with the result. For obtaining a good speedup using the GPU, opt for large number of memory cells and large batch sizes (although not too large, that also has drawbacks).

# %%
# Computing inputs for `create_model`
input_n = len(eng_word_to_ix)
output_n = len(spa_word_to_ix)
X_seq_len = len(X[0])
Y_seq_len = Y_onehot.shape[1]

Xz = np.zeros([22947,1])
# Create the model
# YOUR CODE HERE
model = create_model(input_n, X_seq_len, output_n, Y_seq_len, 512, 512)

# Train the model (note that you should feed both the input sentence and a zero array with the correct shape to
# the `fit` method).
# YOUR CODE HERE
#model.fit([X,Xz], Y_onehot,epochs=20, batch_size=128, validation_split=0.2, verbose=2)

#model.save_weights('seq2seq_model_correct.hdf5')

# If you need, you can use the following line for loading a saved model weights
#model.load_weights('seq2seq_model.hdf5')

# %% [markdown]
# #### 2.2.3 Evaluation <a class="anchor" id="2.2.3"></a>
# You are free to evaluate and compare results of your model(s) in any way you have learned from the deep learning course.
#
# Now motivate your choice of architecture and hyperparameters by answering the questions below.

# %% [markdown]
# **Question:** What loss function, metrics and optimizer did you use and why?

# %% [markdown]
# **Your answer:** (fill in here)

# %% [markdown]
# **Question:** Did you use any Keras callbacks? If so, how did they help you?

# %% [markdown]
# **Your answer:** (fill in here)

# %% [markdown]
# **Question:** How did you evaluate that the model was good enough?

# %% [markdown]
# **Your answer:** (Once the model converges to a minimum point, compare the loss gap between the training data and validation data, if it is )

# %% [markdown]
# #### 2.2.4 Testing <a class="anchor" id="2.2.4"></a>
# Test your neural machine translator on a few sentences by running the test case below. The similarity metric is calculated comparing word embeddings.
#
# You can also use the function `translate` to try your own sentences, just remember that every word needs to be in the vocabulary!

# %%
model = model.load_weights('seq2seq_model_correct.hdf5')
def translate(sentence):
    """ Translate a sentence using `model`. `model` is assumed to be a global variable.
    
    Arguments:
    sentence - a string to translate
    
    Returns:
    the translated sentence as a string
    """
    
    # Check that each of the words in the input sentence exist in the input dictionary
    try:
        x = [eng_word_to_ix[word] for word in sentence.split(' ')]
    except KeyError as e: 
        print('{0} doesn\'t exist in the vocabulary!'.format(e))
        
    # Pad the input sentence
    x = pad_sequences([x], maxlen=SEQ_MAX_LEN, dtype='int32')
    
    # YOUR CODE HERE
    
    y_pred_words = ""
    y_pred_probs = model.predict([x,np.zeros(len(x))])
    for i in range(len(y_pred_probs)):
        for j in range(len(y_pred_probs[i])):
            ix = np.argmax(y_pred_probs[i,j])
            if ix == 0:
                continue
            w = spa_ix_to_word[ix]
            y_pred_words += " " + w
    return y_pred_words

# %%
# test case. be sure the variable model has a reference to your trained model
test_predictions(translate, eng_word_to_ix, spa_ix_to_word, SEQ_MAX_LEN, model)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-2003dc644b16> in <module>()
#       1 # test case. be sure the variable model has a reference to your trained model
# ----> 2 test_predictions(translate, eng_word_to_ix, spa_ix_to_word, SEQ_MAX_LEN, model)
#
# D:\Git\Git\deep-machine-learning\Home Assignments\HA2\utils\tests\ha2Tests.py in test_predictions(translate, sentence, eng_word_to_ix, spa_ix_to_word, model)
#     408     # word embedding
#     409     os.system('python -m spacy download es') # download embedding if needed
# --> 410     nlp = spacy.load('es')
#     411
#     412     for test_case in test_cases:
#
# D:\Python\Anaconda\Anaconda\lib\site-packages\spacy\__init__.py in load(name, **overrides)
#      13     if depr_path not in (True, False, None):
#      14         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 15     return util.load_model(name, **overrides)
#      16
#      17
#
# D:\Python\Anaconda\Anaconda\lib\site-packages\spacy\util.py in load_model(name, **overrides)
#     117     elif hasattr(name, 'exists'):  # Path or Path-like to model data
#     118         return load_model_from_path(name, **overrides)
# --> 119     raise IOError(Errors.E050.format(name=name))
#     120
#     121
#
# OSError: [E050] Can't find model 'es'. It doesn't seem to be a shortcut link, a Python package or a valid path to a data directory.

# %%
# test for yourself
print(translate('this is a dog .'))

# %%
print(translate('she love apples .'))

# %%
print(translate('he opened the window .'))

# %%
print(translate('this is working well .'))

# %%
print(translate('i am a great student .'))

# %% [markdown]
# ## Congratulations!
# You have successfully implemented a recurrent neural network from scratch using only NumPy and also implemented a neural machine translator using Keras!
#
# When choosing the architecture for your neural machine translator you are partly restricted from the capabilities of Keras and partly restricted from your available computing power.
#
# **Question:** Give 3 suggestions for different techniques that can be used to improve your neural machine translator.

# %% [markdown]
# **Your answer:** (fill in here)
